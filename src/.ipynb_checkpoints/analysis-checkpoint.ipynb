# %%
import pickle 
import os, sys, glob

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from field.utils import profiling_rad

# %%
pickled_archive_list = [
    "/home/ribeirogroup/code/mm_polariton_pickle_ja/result_Jul10th_2024_1421_mu1e3/*", #0
    "/home/ribeirogroup/code/mm_polariton_pickle_ja/result_Jul11st_2024_0928/*", #1
    "/home/ribeirogroup/code/mm_polariton_pickle_ja/result_Jul11st_2024_1319/*", #2
    "/home/ribeirogroup/code/mm_polariton_pickle_ja/result_Jul12nd_2024_0939/*", #3 
    "/home/ribeirogroup/code/mm_polariton_pickle_ja/result_Jul13th_2024_0956/*", #4
    "/home/ribeirogroup/code/mm_polariton_pickle_ja/result_Jul15th_2024_0902/*", #5
    "/home/ribeirogroup/code/mm_polariton_pickle_ja/result_Jul15th_2024_1536/*", #6
    "/home/ribeirogroup/code/mm_polariton_pickle_ja/result_Jul16th_2024_1033/*", #7
    "/home/ribeirogroup/code/mm_polariton_pickle_ja/result_Jul16th_2024_1539/*", #8
    "/home/ribeirogroup/code/mm_polariton_pickle_ja/result_Jul17th_2024_0922/*"  #9
]

# %%
def get_all_file_from_path(path):
    file_dict = {"cavity":{}, "free":{}}

    for KEYWORDS in ["free","cavity"]:
        for file in glob.glob(path):

            if os.path.isdir(file):
                continue
            elif KEYWORDS not in file or "result" not in file:
                continue
    
            number = file.split(".")[0]
            number = number.split("_")[-1]
            number = int(number)

            file_dict[KEYWORDS][number] = file
                
    return file_dict

def read_pickle(pickle_path):
    with open(pickle_path,"rb") as handle:
        result = pickle.load(handle)

    return result

def get_descriptor(file_dict):

    descriptor = {}
    
    for KW in ["free","cavity"]:
        
        last_file_path_key = len(file_dict[KW]) - 1
        
        for i,file_path in file_dict[KW].items():
            
            with open(file_path,"rb") as handle:
                result = pickle.load(handle)

            if i == last_file_path_key:
                pass

# %%
all_pickle = get_all_file_from_path(pickled_archive_list[4])
result_cav = read_pickle(all_pickle["cavity"][0])

# %%
result_cav["temperature"]
# Out:
# 200

# %%
cavity_field = result_cav["cavity_field"]
print(cavity_field.L)
print(cavity_field.k_vector * cavity_field.L / (2*np.pi))
# Out:
# 30000000.0
# [[ 0. 62.  0.]
#  [ 0.  0. 62.]
#  [62.  0.  0.]
#  [ 0. 63.  0.]
#  [ 0.  0. 63.]
#  [63.  0.  0.]
#  [ 0. 64.  0.]
#  [64.  0.  0.]
#  [ 0.  0. 64.]
#  [ 0. 65.  0.]
#  [65.  0.  0.]
#  [ 0.  0. 65.]
#  [ 0.  0. 66.]
#  [66.  0.  0.]
#  [ 0. 66.  0.]
#  [ 0. 67.  0.]
#  [ 0.  0. 67.]
#  [67.  0.  0.]
#  [68.  0.  0.]
#  [ 0.  0. 68.]
#  [ 0. 68.  0.]
#  [69.  0.  0.]
#  [ 0.  0. 69.]
#  [ 0. 69.  0.]
#  [ 0. 70.  0.]
#  [70.  0.  0.]
#  [ 0.  0. 70.]
#  [71.  0.  0.]
#  [ 0. 71.  0.]
#  [ 0.  0. 71.]
#  [ 0.  0. 72.]
#  [72.  0.  0.]
#  [ 0. 72.  0.]
#  [ 0. 73.  0.]
#  [ 0.  0. 73.]
#  [73.  0.  0.]
#  [ 0. 74.  0.]
#  [74.  0.  0.]
#  [ 0.  0. 74.]
#  [ 0.  0. 75.]
#  [75.  0.  0.]
#  [ 0. 75.  0.]
#  [ 0. 76.  0.]
#  [76.  0.  0.]
#  [ 0.  0. 76.]
#  [ 0.  0. 77.]
#  [ 0. 77.  0.]
#  [77.  0.  0.]
#  [ 0. 78.  0.]
#  [ 0.  0. 78.]
#  [78.  0.  0.]
#  [ 0. 79.  0.]
#  [ 0.  0. 79.]
#  [79.  0.  0.]
#  [80.  0.  0.]
#  [ 0.  0. 80.]
#  [ 0. 80.  0.]
#  [ 0. 81.  0.]
# ...

# %%
all_pickle = get_all_file_from_path(pickled_archive_list[5])
result_cav = read_pickle(all_pickle["cavity"][0])
print(result_cav["temperature"])
cavity_field = result_cav["cavity_field"]
print(cavity_field.L)
print(cavity_field.k_vector * cavity_field.L / (2*np.pi))
# Out:
# 200
# 30000000.0
# [[ 0. 62.  0.]
#  [ 0.  0. 62.]
#  [62.  0.  0.]
#  [ 0. 63.  0.]
#  [ 0.  0. 63.]
#  [63.  0.  0.]
#  [ 0. 64.  0.]
#  [64.  0.  0.]
#  [ 0.  0. 64.]
#  [ 0. 65.  0.]
#  [65.  0.  0.]
#  [ 0.  0. 65.]
#  [ 0.  0. 66.]
#  [66.  0.  0.]
#  [ 0. 66.  0.]
#  [ 0. 67.  0.]
#  [ 0.  0. 67.]
#  [67.  0.  0.]
#  [68.  0.  0.]
#  [ 0.  0. 68.]
#  [ 0. 68.  0.]
#  [69.  0.  0.]
#  [ 0.  0. 69.]
#  [ 0. 69.  0.]
#  [ 0. 70.  0.]
#  [70.  0.  0.]
#  [ 0.  0. 70.]
#  [71.  0.  0.]
#  [ 0. 71.  0.]
#  [ 0.  0. 71.]
#  [ 0.  0. 72.]
#  [72.  0.  0.]
#  [ 0. 72.  0.]
#  [ 0. 73.  0.]
#  [ 0.  0. 73.]
#  [73.  0.  0.]
#  [ 0. 74.  0.]
#  [74.  0.  0.]
#  [ 0.  0. 74.]
#  [ 0.  0. 75.]
#  [75.  0.  0.]
#  [ 0. 75.  0.]
#  [ 0. 76.  0.]
#  [76.  0.  0.]
#  [ 0.  0. 76.]
#  [ 0.  0. 77.]
#  [ 0. 77.  0.]
#  [77.  0.  0.]
#  [ 0. 78.  0.]
#  [ 0.  0. 78.]
#  [78.  0.  0.]
#  [ 0. 79.  0.]
#  [ 0.  0. 79.]
#  [79.  0.  0.]
#  [80.  0.  0.]
#  [ 0.  0. 80.]
#  [ 0. 80.  0.]
# ...
