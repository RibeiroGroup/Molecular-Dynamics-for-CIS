# %%
import warnings
warnings.filterwarnings('ignore')

import argparse
import os, sys, importlib
from glob import glob
import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import scipy

from utilities import reduced_parameter as red
from field.utils import profiling_rad
from field.electromagnetic import FreeVectorPotential, CavityVectorPotential
from matter.atoms import AtomsInBox
from calculator.calculator import Calculator

from utilities.etc import categorizing_result

import animation as an
from scipy import fft, signal
from analyze_tools.IR_DACF import calc_ACF, calc_FFT

from simulation.single import single_collision_simulation
import utilities.reduced_parameter as red

# %%
s = red.sigma_Ar_Xe
e = red.epsilon_Ar_Xe

re = s * 2 ** (1/6)
k = 4 * e * (156 * (s**12 / re**14) - 42 * (s**6 / re**8))
mu = red.mass_dict['Ar'] * red.mass_dict['Xe'] / (red.mass_dict['Ar'] + red.mass_dict['Xe'])
omega = np.sqrt(k / mu)

vib_freq = omega / (2 * np.pi * red.c * red.sigma)
vib_freq
# Out:
# 22.766978335022763

# %%
potential_function = lambda r:  4 * red.epsilon_Ar_Xe \
            * ( (red.sigma_Ar_Xe/r)**12 - (red.sigma_Ar_Xe/r)**6 )

fig,ax = plt.subplots()

r = np.linspace(1.05, 2.0, 100)
ax.plot(r, potential_function(r))
ax.hlines(0, min(r), max(r), linestyle = 'dotted')

ax.xaxis.set_major_locator(MultipleLocator(0.1))
ax.set_xlabel('Ar - Xe Distance (reduced unit)')
ax.set_ylabel('Energy (reduced unit)')

fig.savefig('figure/potential.jpeg',dpi = 600)

# %%
#
# Define paths to pickle files and functions
#

def assert_path(path):
    try: 
        assert os.path.isdir(path)
    except AssertionError:
        raise Exception("Path {} is not exist".format(path))

def field_spectra(result_dict, limit = None):
    rad_profile = []
    
    for i, rd in result_dict.items():

        if limit and i > limit : 
            continue
        
        Afield = rd["field"]
        
        rad_energy = red.convert_energy(np.array(Afield.history["energy"][-1]), "ev") 
        omega = red.convert_wavenumber(Afield.k_val)
        omega_profile, final_rad_profile = profiling_rad(omega, rad_energy)
        
        foo = np.argsort(omega_profile)
        omega_profile = np.array(omega_profile)[foo]
        final_rad_profile = np.array(final_rad_profile)[foo]
        
        rad_profile.append(final_rad_profile)
        
    rad_profile = np.mean(rad_profile, axis = 0)
    
    return omega_profile, np.array(rad_profile)

def fft_autocorr(t,dp_vel,h,windows='Gaussian'):
    autocorr = calc_ACF(dp_vel)
    yfft = calc_FFT(autocorr, windows)
    yfft = np.nan_to_num(yfft)
    intensity = np.sum(yfft, axis=1)[0:int(len(yfft)/2)]
    
    delta_t = red.convert_time(h) * 1e-12 * 3e10
    wvn = np.fft.fftfreq(len(yfft), delta_t)[0:int(len(yfft)/2)]
    
    return wvn, intensity

def dipole_spectra(
    atoms, h, time_frame = None, 
    quant = 'dipole_velocity', windows = 'Gaussian'):
    #h = result_dict['h']

    if time_frame: 
        ti, tf = time_frame
    dipole_velocity = np.sum(
        atoms.observable[quant], axis = 1)
    dp = np.array(dipole_velocity)
    #dp_vel = np.sum(
    #    result_dict['atoms'].observable['dipole'], axis = 1
    #)

    if time_frame: 
        time = np.array(atoms.observable['t'])
        time -= time[0]
        dp = dp[(time > ti) * (time < tf)]

    wavenumber, ir = fft_autocorr(time, dp, h, windows)

    if quant == 'dipole':
        ir *= wavenumber**2

    return np.array(wavenumber), np.array(ir)

# %%
Lxy = 3e7; Lz = 3e3
def get_ArXePair(d_arxe, v_ar = 0, h = 0, n_pairs = 1, Lxy=Lxy, Lz=Lz):
    """
    """
    atoms = AtomsInBox(
        Lxy = Lxy, Lz = Lz, cell_width = (1e6,1e2), 
        mass_dict = red.mass_dict)

    v_xe = - v_ar / red.mass_dict['Xe']

    for i in range(n_pairs):
        if i == 0:
            r0 = np.zeros(3)
        else:
            r0 = np.hstack(
                [
                    #np.random.uniform(-Lxy/2+10, Lxy/2-10, size = 2), 
                    np.zeros(2),
                    np.random.uniform(-Lz/2+10, Lz/2-10)]
            )
        atoms.add(
                elements = ["Ar"],
                r = np.array([[-h/2,0.0,-d_arxe/2]]) + r0,
                r_dot = np.array([[0.0, 0.0, v_ar]])
                )
        
        atoms.add(
                elements = ["Xe"],
                r = np.array([[h/2,0.0,d_arxe/2]]) + r0,
                r_dot = np.array([[0.00, 0.00, v_xe]])
                )
    
    idxAr = atoms.element_idx(element = "Xe")
    idxXe = atoms.element_idx(element = "Ar")
    epsilon_mat, sigma_mat = red.generate_LJparam_matrix(idxAr = idxAr, idxXe = idxXe)
    
    # calculator to the atoms object
    atoms.add_calculator(
        calculator_class = Calculator,
        calculator_kwargs = {
            "epsilon": epsilon_mat, "sigma" : sigma_mat, 
            "positive_atom_idx" : idxXe, "negative_atom_idx" : idxAr,
            "mu0" : red.mu0, "d" : red.d0, "a" : red.a, 'd7':red.d7
        })
    
    atoms.update_distance()
    
    return atoms

def get_field(coup_str, mode = False, Lxy = Lxy, Lz = Lz):
    if mode == 'multi':
        k_vector_int = np.array(
            [[i,0,0] for i in range(1,100)]
            ,dtype=np.float64)
    elif isinstance(mode, int):
        k_vector_int = np.array([[mode,0,0]])
    else:
        raise Exception('Mode have to be either "multi" or an integer!')
    
    amplitude = np.vstack([
        np.random.uniform(size = 2) * 1 + np.random.uniform(size = 2) * 1j
        for i in range(len(k_vector_int))
        ])
   
    Afield = CavityVectorPotential(
            k_vector_int = k_vector_int, amplitude = amplitude,
            Lxy = Lxy, Lz = Lz, constant_c = red.c, coupling_strength = coup_str * Lxy
            )

    return Afield

# %%
atoms = get_ArXePair(d_arxe = 3, h = 0.8, v_ar = 0.001, n_pairs = 1)

field = get_field(mode = 23, coup_str = 30)
    
t, rd = single_collision_simulation(
    0, h = 1e-2, atoms = atoms, field = field, 
    max_steps = 20000, verbose = True)
# Out:
# Cycle: 0, iterations: 1, potential: -1.0639E-02
# Cycle: 0, iterations: 2, potential: -1.0639E-02
# Cycle: 0, iterations: 3, potential: -1.0640E-02
# Cycle: 0, iterations: 4, potential: -1.0640E-02
# Cycle: 0, iterations: 5, potential: -1.0641E-02
# Cycle: 0, iterations: 6, potential: -1.0641E-02
# Cycle: 0, iterations: 7, potential: -1.0642E-02
# Cycle: 0, iterations: 8, potential: -1.0642E-02
# Cycle: 0, iterations: 9, potential: -1.0643E-02
# Cycle: 0, iterations: 19731, potential: -7.2095E-01
# Cycle: 0, iterations: 19732, potential: -6.9437E-01
# Cycle: 0, iterations: 19733, potential: -6.6935E-01
# Cycle: 0, iterations: 19734, potential: -6.4577E-01
# Cycle: 0, iterations: 19735, potential: -6.2356E-01
# Cycle: 0, iterations: 19736, potential: -6.0262E-01
# Cycle: 0, iterations: 19737, potential: -5.8288E-01
# Cycle: 0, iterations: 19738, potential: -5.6425E-01
# Cycle: 0, iterations: 19739, potential: -5.4666E-01
# Cycle: 0, iterations: 19740, potential: -5.3003E-01
# Cycle: 0, iterations: 19741, potential: -5.1432E-01
# Cycle: 0, iterations: 19742, potential: -4.9945E-01
# Cycle: 0, iterations: 19743, potential: -4.8538E-01
# Cycle: 0, iterations: 19744, potential: -4.7204E-01
# Cycle: 0, iterations: 19745, potential: -4.5940E-01
# Cycle: 0, iterations: 19746, potential: -4.4741E-01
# Cycle: 0, iterations: 19747, potential: -4.3602E-01
# Cycle: 0, iterations: 19748, potential: -4.2520E-01
# Cycle: 0, iterations: 19749, potential: -4.1492E-01
# Cycle: 0, iterations: 19750, potential: -4.0514E-01
# Cycle: 0, iterations: 19751, potential: -3.9583E-01
# Cycle: 0, iterations: 19752, potential: -3.8697E-01
# Cycle: 0, iterations: 19753, potential: -3.7853E-01
# Cycle: 0, iterations: 19754, potential: -3.7048E-01
# Cycle: 0, iterations: 19755, potential: -3.6280E-01
# Cycle: 0, iterations: 19756, potential: -3.5547E-01
# Cycle: 0, iterations: 19757, potential: -3.4847E-01
# Cycle: 0, iterations: 19758, potential: -3.4178E-01
# Cycle: 0, iterations: 19759, potential: -3.3540E-01
# Cycle: 0, iterations: 19760, potential: -3.2929E-01
# Cycle: 0, iterations: 19761, potential: -3.2345E-01
# Cycle: 0, iterations: 19762, potential: -3.1786E-01
# Cycle: 0, iterations: 19763, potential: -3.1251E-01
# Cycle: 0, iterations: 19764, potential: -3.0739E-01
# Cycle: 0, iterations: 19765, potential: -3.0248E-01
# Cycle: 0, iterations: 19766, potential: -2.9778E-01
# Cycle: 0, iterations: 19767, potential: -2.9328E-01
# Cycle: 0, iterations: 19768, potential: -2.8897E-01
# Cycle: 0, iterations: 19769, potential: -2.8483E-01
# Cycle: 0, iterations: 19770, potential: -2.8086E-01
# Cycle: 0, iterations: 19771, potential: -2.7706E-01
# Cycle: 0, iterations: 19772, potential: -2.7341E-01
# Cycle: 0, iterations: 19773, potential: -2.6992E-01
# Cycle: 0, iterations: 19774, potential: -2.6656E-01
# Cycle: 0, iterations: 19775, potential: -2.6334E-01
# Cycle: 0, iterations: 19776, potential: -2.6026E-01
# Cycle: 0, iterations: 19777, potential: -2.5730E-01
# Cycle: 0, iterations: 19778, potential: -2.5446E-01
# Cycle: 0, iterations: 19779, potential: -2.5174E-01
# Cycle: 0, iterations: 19780, potential: -2.4913E-01
# Cycle: 0, iterations: 19781, potential: -2.4663E-01
# Cycle: 0, iterations: 19782, potential: -2.4423E-01
# Cycle: 0, iterations: 19783, potential: -2.4194E-01
# Cycle: 0, iterations: 19784, potential: -2.3974E-01
# Cycle: 0, iterations: 19785, potential: -2.3764E-01
# Cycle: 0, iterations: 19786, potential: -2.3563E-01
# Cycle: 0, iterations: 19787, potential: -2.3370E-01
# Cycle: 0, iterations: 19788, potential: -2.3187E-01
# Cycle: 0, iterations: 19789, potential: -2.3011E-01
# Cycle: 0, iterations: 19790, potential: -2.2844E-01
# Cycle: 0, iterations: 19791, potential: -2.2684E-01
# Cycle: 0, iterations: 19792, potential: -2.2532E-01
# Cycle: 0, iterations: 19793, potential: -2.2387E-01
# Cycle: 0, iterations: 19794, potential: -2.2250E-01
# Cycle: 0, iterations: 19795, potential: -2.2120E-01
# Cycle: 0, iterations: 19796, potential: -2.1996E-01
# Cycle: 0, iterations: 19797, potential: -2.1879E-01
# Cycle: 0, iterations: 19798, potential: -2.1769E-01
# Cycle: 0, iterations: 19799, potential: -2.1666E-01
# Cycle: 0, iterations: 19800, potential: -2.1568E-01
# Cycle: 0, iterations: 19801, potential: -2.1477E-01
# Cycle: 0, iterations: 19802, potential: -2.1392E-01
# Cycle: 0, iterations: 19803, potential: -2.1313E-01
# Cycle: 0, iterations: 19804, potential: -2.1240E-01
# Cycle: 0, iterations: 19805, potential: -2.1173E-01
# Cycle: 0, iterations: 19806, potential: -2.1111E-01
# Cycle: 0, iterations: 19807, potential: -2.1055E-01
# Cycle: 0, iterations: 19808, potential: -2.1005E-01
# Cycle: 0, iterations: 19809, potential: -2.0960E-01
# Cycle: 0, iterations: 19810, potential: -2.0920E-01
# Cycle: 0, iterations: 19811, potential: -2.0887E-01
# Cycle: 0, iterations: 19812, potential: -2.0858E-01
# Cycle: 0, iterations: 19813, potential: -2.0835E-01
# Cycle: 0, iterations: 19814, potential: -2.0817E-01
# Cycle: 0, iterations: 19815, potential: -2.0805E-01
# Cycle: 0, iterations: 19816, potential: -2.0797E-01
# Cycle: 0, iterations: 19817, potential: -2.0795E-01
# Cycle: 0, iterations: 19818, potential: -2.0799E-01
# Cycle: 0, iterations: 19819, potential: -2.0808E-01
# Cycle: 0, iterations: 19820, potential: -2.0822E-01
# Cycle: 0, iterations: 19821, potential: -2.0841E-01
# Cycle: 0, iterations: 19822, potential: -2.0866E-01
# Cycle: 0, iterations: 19823, potential: -2.0896E-01
# Cycle: 0, iterations: 19824, potential: -2.0931E-01
# Cycle: 0, iterations: 19825, potential: -2.0972E-01
# Cycle: 0, iterations: 19826, potential: -2.1018E-01
# Cycle: 0, iterations: 19827, potential: -2.1070E-01
# Cycle: 0, iterations: 19828, potential: -2.1128E-01
# Cycle: 0, iterations: 19829, potential: -2.1191E-01
# Cycle: 0, iterations: 19830, potential: -2.1260E-01
# Cycle: 0, iterations: 19831, potential: -2.1335E-01
# Cycle: 0, iterations: 19832, potential: -2.1416E-01
# Cycle: 0, iterations: 19833, potential: -2.1502E-01
# Cycle: 0, iterations: 19834, potential: -2.1595E-01
# Cycle: 0, iterations: 19835, potential: -2.1694E-01
# Cycle: 0, iterations: 19836, potential: -2.1800E-01
# Cycle: 0, iterations: 19837, potential: -2.1912E-01
# Cycle: 0, iterations: 19838, potential: -2.2031E-01
# Cycle: 0, iterations: 19839, potential: -2.2156E-01
# Cycle: 0, iterations: 19840, potential: -2.2288E-01
# Cycle: 0, iterations: 19841, potential: -2.2428E-01
# Cycle: 0, iterations: 19842, potential: -2.2574E-01
# Cycle: 0, iterations: 19843, potential: -2.2728E-01
# Cycle: 0, iterations: 19844, potential: -2.2890E-01
# Cycle: 0, iterations: 19845, potential: -2.3060E-01
# Cycle: 0, iterations: 19846, potential: -2.3238E-01
# Cycle: 0, iterations: 19847, potential: -2.3424E-01
# Cycle: 0, iterations: 19848, potential: -2.3619E-01
# Cycle: 0, iterations: 19849, potential: -2.3823E-01
# Cycle: 0, iterations: 19850, potential: -2.4036E-01
# Cycle: 0, iterations: 19851, potential: -2.4258E-01
# Cycle: 0, iterations: 19852, potential: -2.4491E-01
# Cycle: 0, iterations: 19853, potential: -2.4733E-01
# Cycle: 0, iterations: 19854, potential: -2.4986E-01
# Cycle: 0, iterations: 19855, potential: -2.5250E-01
# Cycle: 0, iterations: 19856, potential: -2.5526E-01
# Cycle: 0, iterations: 19857, potential: -2.5813E-01
# Cycle: 0, iterations: 19858, potential: -2.6113E-01
# Cycle: 0, iterations: 19859, potential: -2.6425E-01
# Cycle: 0, iterations: 19860, potential: -2.6750E-01
# Cycle: 0, iterations: 19861, potential: -2.7090E-01
# Cycle: 0, iterations: 19862, potential: -2.7444E-01
# Cycle: 0, iterations: 19863, potential: -2.7813E-01
# Cycle: 0, iterations: 19864, potential: -2.8198E-01
# Cycle: 0, iterations: 19865, potential: -2.8599E-01
# Cycle: 0, iterations: 19866, potential: -2.9018E-01
# Cycle: 0, iterations: 19867, potential: -2.9455E-01
# Cycle: 0, iterations: 19868, potential: -2.9910E-01
# Cycle: 0, iterations: 19869, potential: -3.0386E-01
# Cycle: 0, iterations: 19870, potential: -3.0883E-01
# Cycle: 0, iterations: 19871, potential: -3.1401E-01
# Cycle: 0, iterations: 19872, potential: -3.1943E-01
# Cycle: 0, iterations: 19873, potential: -3.2509E-01
# Cycle: 0, iterations: 19874, potential: -3.3100E-01
# Cycle: 0, iterations: 19875, potential: -3.3719E-01
# Cycle: 0, iterations: 19876, potential: -3.4366E-01
# Cycle: 0, iterations: 19877, potential: -3.5043E-01
# Cycle: 0, iterations: 19878, potential: -3.5752E-01
# Cycle: 0, iterations: 19879, potential: -3.6495E-01
# Cycle: 0, iterations: 19880, potential: -3.7273E-01
# Cycle: 0, iterations: 19881, potential: -3.8089E-01
# Cycle: 0, iterations: 19882, potential: -3.8945E-01
# Cycle: 0, iterations: 19883, potential: -3.9844E-01
# Cycle: 0, iterations: 19884, potential: -4.0787E-01
# Cycle: 0, iterations: 19885, potential: -4.1779E-01
# Cycle: 0, iterations: 19886, potential: -4.2822E-01
# Cycle: 0, iterations: 19887, potential: -4.3919E-01
# Cycle: 0, iterations: 19888, potential: -4.5075E-01
# Cycle: 0, iterations: 19889, potential: -4.6292E-01
# Cycle: 0, iterations: 19997, potential: -3.2923E-01
# Cycle: 0, iterations: 19998, potential: -3.2574E-01
# Cycle: 0, iterations: 19999, potential: -3.2243E-01
# Cycle: 0, iterations: 20000, potential: -3.1930E-01

# %%
atoms = rd['atoms']

total_dipole = np.sum(atoms.observable['dipole'], axis = 1)
total_dipole_norm = np.sqrt(
    np.einsum('ni,ni->n', total_dipole, total_dipole))

fig,ax = plt.subplots()

wn, ir = dipole_spectra(
    atoms, h = 1e-2, time_frame = (0,np.inf),
    quant = 'dipole_velocity'
)

ir = ir[(wn < 100) * (wn > 10)]
wn = wn[(wn < 100) * (wn > 10)]

ax.plot(
    wn, ir
)

# %%
total_dipole_norm > 0
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
##################################
#"""
#Single pair of Ar-Xe
#Single mode @ resonance
#Examining the coupling strength
#"""
##################################

single_mode_atoms_dict = {}

for i, ct in enumerate([1, 10,30]):
    
    atoms = get_ArXePair(1.2, n_pairs = 1)
    
    field = get_field(mode = 23, coup_str = ct)
    
    t, rd = single_collision_simulation(
        0, h = 1e-2, atoms = atoms, field = field, 
        max_steps = 10000, verbose = False)
    atoms = rd['atoms']

    single_mode_atoms_dict.update({ct: atoms})

# %%
fig,ax = plt.subplots()

for ct, atoms in single_mode_atoms_dict.items():
    
    wn, ir = dipole_spectra(
        atoms, h = 1e-2, time_frame = (0,1000),
        quant = 'dipole_velocity'
    )
    ir = smooth(ir[(wn < 25) * (wn > 20)])
    wn = wn[(wn < 25) * (wn > 20)]
    
    ax.plot(
        wn, ir, label = "Dipole scaling = {}L".format(ct),
        linestyle = 'dotted' if ct == 1 else None
    )

ax.set_xlabel('Wavenumber (1/cm)')
ax.set_ylabel('Intensity (arbitray unit)')
ax.legend()
fig.savefig('figure/single.jpeg',dpi=600)

# %%
"""
Single pair of Ar-Xe
Multiple mode from 1->100
Examining the coupling strength
"""

multi_mode_atoms_dict = {}

for i, ct in enumerate([1, 10,30]):
    
    atoms = get_ArXePair(1.2)
    
    field = get_field(mode = 'multi', coup_str = ct)
    
    t, rd = single_collision_simulation(
        0, h = 1e-2, atoms = atoms, field = field, 
        max_steps = 10000, verbose = False)
    atoms = rd['atoms']

    multi_mode_atoms_dict.update({ct: atoms})

# %%
fig,ax = plt.subplots()

for ct, atoms in multi_mode_atoms_dict.items():
    wn, ir = dipole_spectra(atoms, h = 1e-2, time_frame = (0,1000), quant = 'dipole_velocity')
    ir = ir[(wn < 26) * (wn > 20)]
    wn = wn[(wn < 26) * (wn > 20)]

    ax.plot(
        wn, ir, label = "Dipole scaling = {}L".format(ct),
        linestyle = 'dotted' if ct == 1 else None
    )

ax.set_xlabel('Wavenumber (1/cm)')
ax.set_ylabel('Intensity (arbitray unit)')
ax.legend()
fig.savefig('figure/multiple.jpeg',dpi=600)

# %%
"""
Single pair of Ar-Xe
Single mode @ resonance
Examining the Ar-Xe initial distance
"""
single_mode_datoms_dict = {}

for i, d in enumerate([1.1, 1.15, 1.2, 1.3]):
    
    atoms = get_ArXePair(d)
    
    field = get_field(mode = 23, coup_str = 30)
    
    t, rd = single_collision_simulation(
        0, h = 1e-2, atoms = atoms, field = field, 
        max_steps = 20000, verbose = False)
    atoms = rd['atoms']

    single_mode_datoms_dict.update({d: atoms})

# %%
fig,ax = plt.subplots(2, figsize = (6,8))

for d, atoms in single_mode_datoms_dict.items():
    
    wn, ir = dipole_spectra(atoms, h = 1e-2, time_frame = (0,1000))
    
    if d == 1.4 or d == 1.1: 
        i = 1
        ir = ir[(wn < 100) * (wn > 0)]
        wn = wn[(wn < 100) * (wn > 0)]
    else: 
        i = 0
        ir = ir[(wn < 45) * (wn > 18)]
        wn = wn[(wn < 45) * (wn > 18)]
    
    ax[i].plot(
        wn, ir, label = "Ar-Xe dist. = {}".format(d)
    )

#ax.set_xlabel('Wavenumber (1/cm)')
#ax.set_ylabel('Intensity (arbitray unit)')
ax[0].legend()
ax[1].legend()
fig.savefig('figure/single_distance.jpeg',dpi=600)

# %%
"""
Single pair of Ar-Xe
Multiple mode from 1->100
Examining the Ar-Xe initial distance
"""
multi_mode_datoms_dict = {}

for i, d in enumerate([1.1, 1.15, 1.2, 1.3]):
    
    atoms = get_ArXePair(d)
    
    field = get_field(mode = 'multi', coup_str = 30)
    
    t, rd = single_collision_simulation(
        0, h = 1e-2, atoms = atoms, field = field, 
        max_steps = 10000, verbose = False)
    atoms = rd['atoms']

    multi_mode_datoms_dict.update({d: atoms})

# %%
fig,ax = plt.subplots(2, figsize = (6,8))

for d, atoms in multi_mode_datoms_dict.items():
    
    wn, ir = dipole_spectra(atoms, h = 1e-2, time_frame = (0,1000), quant = 'dipole_velocity')
    
    if d == 1.4 or d == 1.1: 
        i = 1
        ir = ir[(wn < 30) * (wn > 15)]
        wn = wn[(wn < 30) * (wn > 15)]
    else: 
        i = 0
        ir = ir[(wn < 30) * (wn > 15)]
        wn = wn[(wn < 30) * (wn > 15)]
    
    ax[i].plot(
        wn, ir, label = "Ar-Xe dist. = {}".format(d)
    )

#ax.set_xlabel('Wavenumber (1/cm)')
#ax.set_ylabel('Intensity (arbitray unit)')
ax[0].legend()
ax[1].legend()
fig.savefig('figure/multi_distance.jpeg',dpi=600)

# %%
"""
Multiple pair of Ar-Xe
Single mode @ resonance
Examining the coupling strength
"""

single_mode_atoms_dict = {}

np.random.seed(100)

for i, ct in enumerate([10, 20, 50]):
    
    atoms = get_ArXePair(1.21, n_pairs = 16)
    
    field = get_field(mode = 23, coup_str = ct)
    
    t, rd = single_collision_simulation(
        0, h = 1e-2, atoms = atoms, field = field, 
        max_steps = 10000, verbose = False)
    atoms = rd['atoms']

    single_mode_atoms_dict.update({ct: atoms})

# %%
fig,ax = plt.subplots(3)

for i, (ct, atoms) in enumerate(single_mode_atoms_dict.items()):
    #if ct == 5:continue
    wn, ir = dipole_spectra(
        atoms, h = 1e-2, time_frame = (50,np.inf),
        quant = 'dipole_velocity', windows = 'BH'
    )
    ir = ir[(wn < 40) * (wn > 10)]
    wn = wn[(wn < 40) * (wn > 10)]
    
    ax[i].plot(
        wn, ir, label = "Dipole scaling = {}L".format(ct),
    )

#ax.set_xlabel('Wavenumber (1/cm)')
#ax.set_ylabel('Intensity (arbitray unit)')
ax[0].legend()
ax[1].legend()
ax[2].legend()
fig.savefig('figure/multicomplex_single.jpeg',dpi=600)

# %%
atoms = single_mode_atoms_dict[5]
dpv = np.array(atoms.observable['dipole_velocity'])

i = 7
single_dpv = dpv[:,2*i,:] + dpv[:,2*i+1,:]
time = atoms.observable['t']

# %%
wn, ir = fft_autocorr(time, single_dpv, 1e-2, windows = 'BH')

# %%
fig,ax = plt.subplots()

ax.plot(wn,ir)
ax.set_xlim(10,30)

# %%
R = np.array(atoms.trajectory['r'])

R[0,0,:] - R[0,1,:]
