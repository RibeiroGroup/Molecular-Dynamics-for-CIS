# %%
import warnings
warnings.filterwarnings('ignore')

import argparse
import os, sys, importlib
from glob import glob
import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import scipy

from utilities import reduced_parameter as red
from field.electromagnetic import FreeVectorPotential, CavityVectorPotential

from matter.atoms import AtomsInBox
from calculator.calculator import Calculator

from utilities.etc import categorizing_result

import animation as an
import analyze_tools.utils as at

from simulation.single import single_collision_simulation
import utilities.reduced_parameter as red

# %%
s = red.sigma_Ar_Xe
e = red.epsilon_Ar_Xe

re = s * 2 ** (1/6)
k = 4 * e * (156 * (s**12 / re**14) - 42 * (s**6 / re**8))
mu = red.mass_dict['Ar'] * red.mass_dict['Xe'] / (red.mass_dict['Ar'] + red.mass_dict['Xe'])
omega = np.sqrt(k / mu)

vib_freq = omega / (2 * np.pi * red.c * red.sigma)
vib_freq
# Out:
# 22.766978335022763

# %%
potential_function = lambda r:  4 * red.epsilon_Ar_Xe \
            * ( (red.sigma_Ar_Xe/r)**12 - (red.sigma_Ar_Xe/r)**6 )

fig,ax = plt.subplots()

r = np.linspace(1.05, 2.0, 100)
ax.plot(r, potential_function(r))
ax.hlines(0, min(r), max(r), linestyle = 'dotted')

ax.xaxis.set_major_locator(MultipleLocator(0.1))
ax.set_xlabel('Ar - Xe Distance (reduced unit)')
ax.set_ylabel('Energy (reduced unit)')

fig.savefig('figure/potential.jpeg',dpi = 600)

# %%
Lxy = 3e7; Lz = 3e3
def get_ArXePair(d_arxe, v_ar = 0, h = 0, n_pairs = 1, Lxy=Lxy, Lz=Lz):
    """
    """
    atoms = AtomsInBox(
        Lxy = Lxy, Lz = Lz, cell_width = (1e6,1e2), 
        mass_dict = red.mass_dict)

    v_xe = - v_ar / 3

    for i in range(n_pairs):
        if i == 0:
            r0 = np.zeros(3)
        else:
            r0 = np.hstack(
                [
                    #np.random.uniform(-Lxy/2+10, Lxy/2-10, size = 2), 
                    np.zeros(2),
                    np.random.uniform(-Lz/2+10, Lz/2-10)]
            )
        atoms.add(
                elements = ["Ar"],
                r = np.array([[h,0.0,-d_arxe/2]]) + r0,
                r_dot = np.array([[0.0, 0.0, v_ar]])# / np.sqrt(2)
                )
        
        atoms.add(
                elements = ["Xe"],
                r = np.array([[0.0,0.0,d_arxe/2]]) + r0,
                r_dot = np.array([[0.00, 0.00, v_xe]])# / np.sqrt(2)
                )
    
    idxAr = atoms.element_idx(element = "Ar")
    idxXe = atoms.element_idx(element = "Xe")
    epsilon_mat, sigma_mat = red.generate_LJparam_matrix(idxAr = idxAr, idxXe = idxXe)
    
    # calculator to the atoms object
    atoms.add_calculator(
        calculator_class = Calculator,
        calculator_kwargs = {
            "epsilon": epsilon_mat, "sigma" : sigma_mat, 
            "positive_atom_idx" : idxXe, "negative_atom_idx" : idxAr,
            "mu0" : red.mu0, "d" : red.d0, "a" : red.a, 'd7':red.d7
        })
    
    atoms.update_distance()
    
    return atoms

def get_field(coup_str, mode = False, Lxy = Lxy, Lz = Lz):
    if mode == 'multi':
        k_vector_int = np.array(
            [[i,0,0] for i in range(1,100)]
            ,dtype=np.float64)
    elif isinstance(mode, int):
        k_vector_int = np.array([[mode,0,0]])
    elif isinstance(mode, list):
        k_vector_int = np.array(
            [[i,0,0] for i in mode], 
            dtype = np.float64)
    else:
        raise Exception('Mode have to be either "multi" or an integer!')
    
    amplitude = np.vstack([
        np.random.uniform(size = 2) * 1 + np.random.uniform(size = 2) * 1j
        for i in range(len(k_vector_int))
        ])
   
    Afield = CavityVectorPotential(
            k_vector_int = k_vector_int, amplitude = amplitude,
            Lxy = Lxy, Lz = Lz, constant_c = red.c, coupling_strength = coup_str * Lxy
            )

    return Afield

# %%
atoms = get_ArXePair(d_arxe = 4, h = 0 , v_ar = 0.03, n_pairs = 1)

field = get_field(mode = 'multi', coup_str = 20)
    
t, rd = single_collision_simulation(
    0, h = 1e-2, atoms = atoms, field = field, 
    max_steps = 10000, verbose = True)
# Out:
# Cycle: 0, iterations: 1, potential: -2.3317E-03
# Cycle: 0, iterations: 2, potential: -2.3331E-03
# Cycle: 0, iterations: 3, potential: -2.3345E-03
# Cycle: 0, iterations: 4, potential: -2.3359E-03
# Cycle: 0, iterations: 5, potential: -2.3373E-03
# Cycle: 0, iterations: 6, potential: -2.3387E-03
# Cycle: 0, iterations: 7, potential: -2.3401E-03
# Cycle: 0, iterations: 8, potential: -2.3415E-03
# Cycle: 0, iterations: 9, potential: -2.3430E-03
# Cycle: 0, iterations: 10, potential: -2.3444E-03
# Cycle: 0, iterations: 11, potential: -2.3458E-03
# Cycle: 0, iterations: 12, potential: -2.3472E-03
# Cycle: 0, iterations: 13, potential: -2.3487E-03
# Cycle: 0, iterations: 14, potential: -2.3501E-03
# Cycle: 0, iterations: 15, potential: -2.3515E-03
# Cycle: 0, iterations: 16, potential: -2.3530E-03
# Cycle: 0, iterations: 17, potential: -2.3544E-03
# Cycle: 0, iterations: 18, potential: -2.3559E-03
# Cycle: 0, iterations: 19, potential: -2.3573E-03
# Cycle: 0, iterations: 20, potential: -2.3588E-03
# Cycle: 0, iterations: 21, potential: -2.3602E-03
# Cycle: 0, iterations: 22, potential: -2.3617E-03
# Cycle: 0, iterations: 23, potential: -2.3631E-03
# Cycle: 0, iterations: 24, potential: -2.3646E-03
# Cycle: 0, iterations: 25, potential: -2.3660E-03
# Cycle: 0, iterations: 26, potential: -2.3675E-03
# Cycle: 0, iterations: 27, potential: -2.3690E-03
# Cycle: 0, iterations: 28, potential: -2.3704E-03
# Cycle: 0, iterations: 29, potential: -2.3719E-03
# Cycle: 0, iterations: 30, potential: -2.3734E-03
# Cycle: 0, iterations: 31, potential: -2.3749E-03
# Cycle: 0, iterations: 32, potential: -2.3764E-03
# Cycle: 0, iterations: 33, potential: -2.3778E-03
# Cycle: 0, iterations: 34, potential: -2.3793E-03
# Cycle: 0, iterations: 35, potential: -2.3808E-03
# Cycle: 0, iterations: 36, potential: -2.3823E-03
# Cycle: 0, iterations: 37, potential: -2.3838E-03
# Cycle: 0, iterations: 38, potential: -2.3853E-03
# Cycle: 0, iterations: 39, potential: -2.3868E-03
# Cycle: 0, iterations: 9799, potential: -1.3823E+00
# Cycle: 0, iterations: 9800, potential: -1.3823E+00
# Cycle: 0, iterations: 9801, potential: -1.3823E+00
# Cycle: 0, iterations: 9802, potential: -1.3823E+00
# Cycle: 0, iterations: 9803, potential: -1.3824E+00
# Cycle: 0, iterations: 9804, potential: -1.3824E+00
# Cycle: 0, iterations: 9805, potential: -1.3825E+00
# Cycle: 0, iterations: 9806, potential: -1.3825E+00
# Cycle: 0, iterations: 9807, potential: -1.3825E+00
# Cycle: 0, iterations: 9808, potential: -1.3824E+00
# Cycle: 0, iterations: 9809, potential: -1.3823E+00
# Cycle: 0, iterations: 9810, potential: -1.3821E+00
# Cycle: 0, iterations: 9811, potential: -1.3818E+00
# Cycle: 0, iterations: 9812, potential: -1.3815E+00
# Cycle: 0, iterations: 9813, potential: -1.3812E+00
# Cycle: 0, iterations: 9814, potential: -1.3809E+00
# Cycle: 0, iterations: 9815, potential: -1.3805E+00
# Cycle: 0, iterations: 9816, potential: -1.3802E+00
# Cycle: 0, iterations: 9817, potential: -1.3800E+00
# Cycle: 0, iterations: 9818, potential: -1.3798E+00
# Cycle: 0, iterations: 9819, potential: -1.3797E+00
# Cycle: 0, iterations: 9820, potential: -1.3796E+00
# Cycle: 0, iterations: 9821, potential: -1.3796E+00
# Cycle: 0, iterations: 9822, potential: -1.3796E+00
# Cycle: 0, iterations: 9823, potential: -1.3797E+00
# Cycle: 0, iterations: 9824, potential: -1.3799E+00
# Cycle: 0, iterations: 9825, potential: -1.3800E+00
# Cycle: 0, iterations: 9826, potential: -1.3802E+00
# Cycle: 0, iterations: 9827, potential: -1.3804E+00
# Cycle: 0, iterations: 9828, potential: -1.3806E+00
# Cycle: 0, iterations: 9829, potential: -1.3808E+00
# Cycle: 0, iterations: 9830, potential: -1.3810E+00
# Cycle: 0, iterations: 9831, potential: -1.3812E+00
# Cycle: 0, iterations: 9832, potential: -1.3814E+00
# Cycle: 0, iterations: 9833, potential: -1.3815E+00
# Cycle: 0, iterations: 9834, potential: -1.3817E+00
# Cycle: 0, iterations: 9835, potential: -1.3818E+00
# Cycle: 0, iterations: 9836, potential: -1.3820E+00
# Cycle: 0, iterations: 9837, potential: -1.3821E+00
# Cycle: 0, iterations: 9838, potential: -1.3822E+00
# Cycle: 0, iterations: 9839, potential: -1.3823E+00
# Cycle: 0, iterations: 9840, potential: -1.3824E+00
# Cycle: 0, iterations: 9841, potential: -1.3824E+00
# Cycle: 0, iterations: 9842, potential: -1.3825E+00
# Cycle: 0, iterations: 9843, potential: -1.3825E+00
# Cycle: 0, iterations: 9844, potential: -1.3825E+00
# Cycle: 0, iterations: 9845, potential: -1.3825E+00
# Cycle: 0, iterations: 9846, potential: -1.3825E+00
# Cycle: 0, iterations: 9847, potential: -1.3825E+00
# Cycle: 0, iterations: 9848, potential: -1.3824E+00
# Cycle: 0, iterations: 9849, potential: -1.3823E+00
# Cycle: 0, iterations: 9850, potential: -1.3822E+00
# Cycle: 0, iterations: 9851, potential: -1.3821E+00
# Cycle: 0, iterations: 9957, potential: -1.3824E+00
# Cycle: 0, iterations: 9958, potential: -1.3825E+00
# Cycle: 0, iterations: 9959, potential: -1.3819E+00
# Cycle: 0, iterations: 9960, potential: -1.3806E+00
# Cycle: 0, iterations: 9961, potential: -1.3788E+00
# Cycle: 0, iterations: 9962, potential: -1.3764E+00
# Cycle: 0, iterations: 9963, potential: -1.3737E+00
# Cycle: 0, iterations: 9964, potential: -1.3706E+00
# Cycle: 0, iterations: 9965, potential: -1.3674E+00
# Cycle: 0, iterations: 9966, potential: -1.3641E+00
# Cycle: 0, iterations: 9967, potential: -1.3608E+00
# Cycle: 0, iterations: 9968, potential: -1.3576E+00
# Cycle: 0, iterations: 9969, potential: -1.3545E+00
# Cycle: 0, iterations: 9970, potential: -1.3517E+00
# Cycle: 0, iterations: 9971, potential: -1.3492E+00
# Cycle: 0, iterations: 9972, potential: -1.3470E+00
# Cycle: 0, iterations: 9973, potential: -1.3452E+00
# Cycle: 0, iterations: 9974, potential: -1.3437E+00
# Cycle: 0, iterations: 9975, potential: -1.3427E+00
# Cycle: 0, iterations: 9976, potential: -1.3420E+00
# Cycle: 0, iterations: 9977, potential: -1.3418E+00
# Cycle: 0, iterations: 9978, potential: -1.3419E+00
# Cycle: 0, iterations: 9979, potential: -1.3425E+00
# Cycle: 0, iterations: 9980, potential: -1.3434E+00
# Cycle: 0, iterations: 9981, potential: -1.3446E+00
# Cycle: 0, iterations: 9982, potential: -1.3462E+00
# Cycle: 0, iterations: 9983, potential: -1.3481E+00
# Cycle: 0, iterations: 9984, potential: -1.3502E+00
# Cycle: 0, iterations: 9985, potential: -1.3526E+00
# Cycle: 0, iterations: 9986, potential: -1.3551E+00
# Cycle: 0, iterations: 9987, potential: -1.3578E+00
# Cycle: 0, iterations: 9988, potential: -1.3606E+00
# Cycle: 0, iterations: 9989, potential: -1.3635E+00
# Cycle: 0, iterations: 9990, potential: -1.3664E+00
# Cycle: 0, iterations: 9991, potential: -1.3692E+00
# Cycle: 0, iterations: 9992, potential: -1.3719E+00
# Cycle: 0, iterations: 9993, potential: -1.3744E+00
# Cycle: 0, iterations: 9994, potential: -1.3767E+00
# Cycle: 0, iterations: 9995, potential: -1.3787E+00
# Cycle: 0, iterations: 9996, potential: -1.3803E+00
# Cycle: 0, iterations: 9997, potential: -1.3815E+00
# Cycle: 0, iterations: 9998, potential: -1.3823E+00
# Cycle: 0, iterations: 9999, potential: -1.3825E+00
# Cycle: 0, iterations: 10000, potential: -1.3822E+00

# %%
rd
# Out:
# {'atoms': <matter.atoms.AtomsInBox at 0x7712d0a51fd0>,
#  'field': <field.electromagnetic.CavityVectorPotential at 0x7712d196a480>}

# %%
Afield = rd['field']

rad_energy = red.convert_energy(np.array(Afield.history["energy"][-1]), "ev") 
omega = red.convert_wavenumber(Afield.k_val)
omega_profile, final_rad_profile = at.profiling_rad(omega, rad_energy)

# %%
fig,ax = plt.subplots()

ax.scatter(omega_profile, final_rad_profile)

# %%
atoms = rd['atoms']

total_dipole = np.sum(atoms.observable['dipole'], axis = 1)
total_dipole_norm = np.sqrt(
    np.einsum('ni,ni->n', total_dipole, total_dipole))

fig,ax = plt.subplots()

wn, ir = at.dipole_spectra(
    atoms, dtps = red.convert_time(1e-2), 
    time_frame = (0,np.inf), quant = 'dipole_velocity'
)

ir = ir[(wn < 30) * (wn > 15)]
wn = wn[(wn < 30) * (wn > 15)]

ax.plot(
    wn, ir
)

ax.vlines(vib_freq, min(ir), max(ir), linestyle = 'dotted')

# %%
total_dipole_norm > 0

# %%
##################################
#"""
#Single pair of Ar-Xe
#Single mode @ resonance
#Examining the coupling strength
#"""
##################################

single_mode_atoms_dict = {}

for i, ct in enumerate([1, 10,30]):
    
    atoms = get_ArXePair(1.2, n_pairs = 1)
    
    field = get_field(mode = 23, coup_str = ct)
    
    t, rd = single_collision_simulation(
        0, h = 1e-2, atoms = atoms, field = field, 
        max_steps = 10000, verbose = False)
    atoms = rd['atoms']

    single_mode_atoms_dict.update({ct: atoms})

# %%
fig,ax = plt.subplots()

for ct, atoms in single_mode_atoms_dict.items():
    
    wn, ir = dipole_spectra(
        atoms, h = 1e-2, time_frame = (0,1000),
        quant = 'dipole_velocity'
    )
    ir = smooth(ir[(wn < 25) * (wn > 20)])
    wn = wn[(wn < 25) * (wn > 20)]
    
    ax.plot(
        wn, ir, label = "Dipole scaling = {}L".format(ct),
        linestyle = 'dotted' if ct == 1 else None
    )

ax.set_xlabel('Wavenumber (1/cm)')
ax.set_ylabel('Intensity (arbitray unit)')
ax.legend()
fig.savefig('figure/single.jpeg',dpi=600)

# %%
"""
Single pair of Ar-Xe
Multiple mode from 1->100
Examining the coupling strength
"""

multi_mode_atoms_dict = {}

for i, ct in enumerate([1, 10,30]):
    
    atoms = get_ArXePair(1.2)
    
    field = get_field(mode = 'multi', coup_str = ct)
    
    t, rd = single_collision_simulation(
        0, h = 1e-2, atoms = atoms, field = field, 
        max_steps = 10000, verbose = False)
    atoms = rd['atoms']

    multi_mode_atoms_dict.update({ct: atoms})

# %%
fig,ax = plt.subplots()

for ct, atoms in multi_mode_atoms_dict.items():
    wn, ir = dipole_spectra(atoms, h = 1e-2, time_frame = (0,1000), quant = 'dipole_velocity')
    ir = ir[(wn < 26) * (wn > 20)]
    wn = wn[(wn < 26) * (wn > 20)]

    ax.plot(
        wn, ir, label = "Dipole scaling = {}L".format(ct),
        linestyle = 'dotted' if ct == 1 else None
    )

ax.set_xlabel('Wavenumber (1/cm)')
ax.set_ylabel('Intensity (arbitray unit)')
ax.legend()
fig.savefig('figure/multiple.jpeg',dpi=600)

# %%
"""
Single pair of Ar-Xe
Single mode @ resonance
Examining the Ar-Xe initial distance
"""
single_mode_datoms_dict = {}

for i, d in enumerate([1.1, 1.15, 1.2, 1.3]):
    
    atoms = get_ArXePair(d)
    
    field = get_field(mode = 23, coup_str = 30)
    
    t, rd = single_collision_simulation(
        0, h = 1e-2, atoms = atoms, field = field, 
        max_steps = 20000, verbose = False)
    atoms = rd['atoms']

    single_mode_datoms_dict.update({d: atoms})

# %%
fig,ax = plt.subplots(2, figsize = (6,8))

for d, atoms in single_mode_datoms_dict.items():
    
    wn, ir = dipole_spectra(atoms, h = 1e-2, time_frame = (0,1000))
    
    if d == 1.4 or d == 1.1: 
        i = 1
        ir = ir[(wn < 100) * (wn > 0)]
        wn = wn[(wn < 100) * (wn > 0)]
    else: 
        i = 0
        ir = ir[(wn < 45) * (wn > 18)]
        wn = wn[(wn < 45) * (wn > 18)]
    
    ax[i].plot(
        wn, ir, label = "Ar-Xe dist. = {}".format(d)
    )

#ax.set_xlabel('Wavenumber (1/cm)')
#ax.set_ylabel('Intensity (arbitray unit)')
ax[0].legend()
ax[1].legend()
fig.savefig('figure/single_distance.jpeg',dpi=600)

# %%
"""
Single pair of Ar-Xe
Multiple mode from 1->100
Examining the Ar-Xe initial distance
"""
multi_mode_datoms_dict = {}

for i, d in enumerate([1.1, 1.15, 1.2, 1.3]):
    
    atoms = get_ArXePair(d)
    
    field = get_field(mode = 'multi', coup_str = 30)
    
    t, rd = single_collision_simulation(
        0, h = 1e-2, atoms = atoms, field = field, 
        max_steps = 10000, verbose = False)
    atoms = rd['atoms']

    multi_mode_datoms_dict.update({d: atoms})

# %%
fig,ax = plt.subplots(2, figsize = (6,8))

for d, atoms in multi_mode_datoms_dict.items():
    
    wn, ir = dipole_spectra(atoms, h = 1e-2, time_frame = (0,1000), quant = 'dipole_velocity')
    
    if d == 1.4 or d == 1.1: 
        i = 1
        ir = ir[(wn < 30) * (wn > 15)]
        wn = wn[(wn < 30) * (wn > 15)]
    else: 
        i = 0
        ir = ir[(wn < 30) * (wn > 15)]
        wn = wn[(wn < 30) * (wn > 15)]
    
    ax[i].plot(
        wn, ir, label = "Ar-Xe dist. = {}".format(d)
    )

#ax.set_xlabel('Wavenumber (1/cm)')
#ax.set_ylabel('Intensity (arbitray unit)')
ax[0].legend()
ax[1].legend()
fig.savefig('figure/multi_distance.jpeg',dpi=600)

# %%
"""
Multiple pair of Ar-Xe
Single mode @ resonance
Examining the coupling strength
"""

single_mode_atoms_dict = {}

np.random.seed(100)

for i, ct in enumerate([10, 20, 50]):
    
    atoms = get_ArXePair(1.21, n_pairs = 16)
    
    field = get_field(mode = 23, coup_str = ct)
    
    t, rd = single_collision_simulation(
        0, h = 1e-2, atoms = atoms, field = field, 
        max_steps = 10000, verbose = False)
    atoms = rd['atoms']

    single_mode_atoms_dict.update({ct: atoms})

# %%
fig,ax = plt.subplots(3)

for i, (ct, atoms) in enumerate(single_mode_atoms_dict.items()):
    #if ct == 5:continue
    wn, ir = dipole_spectra(
        atoms, h = 1e-2, time_frame = (50,np.inf),
        quant = 'dipole_velocity', windows = 'BH'
    )
    ir = ir[(wn < 40) * (wn > 10)]
    wn = wn[(wn < 40) * (wn > 10)]
    
    ax[i].plot(
        wn, ir, label = "Dipole scaling = {}L".format(ct),
    )

#ax.set_xlabel('Wavenumber (1/cm)')
#ax.set_ylabel('Intensity (arbitray unit)')
ax[0].legend()
ax[1].legend()
ax[2].legend()
fig.savefig('figure/multicomplex_single.jpeg',dpi=600)

# %%
atoms = single_mode_atoms_dict[5]
dpv = np.array(atoms.observable['dipole_velocity'])

i = 7
single_dpv = dpv[:,2*i,:] + dpv[:,2*i+1,:]
time = atoms.observable['t']

# %%
wn, ir = fft_autocorr(time, single_dpv, 1e-2, windows = 'BH')

# %%
fig,ax = plt.subplots()

ax.plot(wn,ir)
ax.set_xlim(10,30)

# %%
R = np.array(atoms.trajectory['r'])

R[0,0,:] - R[0,1,:]
