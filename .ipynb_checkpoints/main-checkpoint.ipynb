# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import sympy as sm
from scipy.constants import m_e,m_p,m_n

from utils import timeit, PBC_wrapping
from forcefield import LennardJonesPotential, construct_param_matrix
from simpleMD import compute_Hem
import constants

# %% [markdown]
# The Jacobi of the dipole function has the form:
# \begin{align*}
#     \begin{bmatrix}
#     \partial \mu_x / \partial r_x & \partial \mu_y / \partial r_x & \partial \mu_z / \partial r_x
#     \\
#     \partial \mu_x / \partial r_y & \partial \mu_y / \partial r_y & \partial \mu_z / \partial r_y
#     \\
#     \partial \mu_x / \partial r_z & \partial \mu_y / \partial r_z & \partial \mu_z / \partial r_z
#     \end{bmatrix}
# \end{align*}

# %%
sm_Rax = sm.symbols("Rax")
sm_Ray = sm.symbols("Ray")
sm_Raz = sm.symbols("Raz")
sm_Ra = [sm_Rax, sm_Ray, sm_Raz]

sm_Rbx = sm.symbols("Rbx")
sm_Rby = sm.symbols("Rby")
sm_Rbz = sm.symbols("Rbz")
sm_Rb = [sm_Rbx, sm_Rby, sm_Rbz]

sm_mu0 = sm.symbols("mu0")
sm_a = sm.symbols("a")
sm_d0 = sm.symbols("d0")
sm_d1 = sm.symbols("d1")
sm_d2 = sm.symbols("d2")
sm_d7 = sm.symbols("d7")

class SymbolicBaseDipoleFunction:
    def __init__(self):
        
        self.dipole_function = [
            sm.lambdify(
            [sm_Rax, sm_Ray, sm_Raz, sm_Rbx, sm_Rby, sm_Rbz, 
             ] + self.parameters_sm, 
                dipole_exp
        ) for dipole_exp in self.dipole_exp]
        
        self.generate_Jacobi()
        #self.generate_Hessian()

    def generate_Jacobi(self):
        self.Ja_exp = [[],[],[]]
        self.Ja_func = [[],[],[]]

        self.Jb_exp = [[],[],[]]
        self.Jb_func = [[],[],[]]

        for i,Ra in enumerate(sm_Ra):
            for j,dipole_f in enumerate(self.dipole_exp):
                d_mu = sm.diff(dipole_f, Ra)
                self.Ja_exp[i].append(d_mu)
                self.Ja_func[i].append(sm.lambdify(
                    [sm_Rax, sm_Ray, sm_Raz, sm_Rbx, sm_Rby, sm_Rbz, 
                    ]+ self.parameters_sm, d_mu
                ))

                d_mu = sm.diff(dipole_f, sm_Rb[i])
                self.Jb_exp[i].append(d_mu)
                self.Jb_func[i].append(sm.lambdify(
                    [sm_Rax, sm_Ray, sm_Raz, sm_Rbx, sm_Rby, sm_Rbz, 
                    ]+ self.parameters_sm, d_mu
                ))

    def __call__(self, r):
        """
        Note: 
        ra should be the positive particle and 
        rb should be the negative particle
        """
        ra = list(r[0])
        rb = list(r[1])

        args = ra + rb + self.parameters

        result = [dipole_f(*args) for dipole_f in self.dipole_function]
        
        return result

    def gradient(self,r,sign):
        ra = list(r[0])
        rb = list(r[1])
        args = ra + rb + self.parameters

        all_result = []
        for sign_ in sign:
            result = np.zeros((3,3))
            
            if sign_ == "+": 
                J_func = self.Ja_func
            elif sign_ == "-": 
                J_func = self.Jb_func
                
            for i, dmu_dRa in enumerate(J_func):
                for j, dmu_i_dRa in enumerate(dmu_dRa):
                    result[i,j] = dmu_i_dRa(*args)

            all_result.append(result)

        return all_result
    
class SymbolicGriegorievDipoleFunction(SymbolicBaseDipoleFunction):
    def __init__(self, mu0, a, d0, d7):

        sm_d = ((sm_Rax - sm_Rbx)**2 + (sm_Ray - sm_Rby)**2 \
             + (sm_Raz - sm_Rbz)**2)**(1/2)
        
        self.parameters = [mu0, a, d0, d7]
        self.parameters_sm = [sm_mu0, sm_a, sm_d0, sm_d7]
        self.dipole_exp = [
            ((sm_Ra[i] - sm_Rb[i])/sm_d) *\
            (sm_mu0 * sm.exp(-sm_a*(sm_d-sm_d0)))# - sm_d7/(sm_d**7))
            for i in range(3)
        ]
        
        super().__init__()

class SimpleGriegorievDipoleFunction:
    def __init__(self, mu0, a, d0, L=None):
        self.mu0 = mu0
        self.a = a
        self.d0 = d0
        self.L = L

    def __call__(self,r_plus,r_minus):
        rij = PBC_wrapping(r_plus - r_minus, self.L)
        d = np.sqrt(np.sum(rij**2))

        return self.mu0 * np.exp(-self.a * (d - self.d0)) * rij / d

    def gradient(self,r_plus,r_minus):
        rij = PBC_wrapping(r_plus - r_minus, self.L)
        d2 = np.sum(rij**2)
        d = np.sqrt(d2)

        rij_outer = np.outer(rij, rij)
        mu_exp = self.mu0 * np.exp(-self.a * (d - self.d0))
        
        grad_mu =  - self.a * rij_outer * mu_exp / d2 
        grad_mu += - mu_exp * rij_outer / (d2 * d)
        grad_mu += mu_exp * np.eye(3) / d

        return [grad_mu, -grad_mu]
        

dipole_function1 = SymbolicGriegorievDipoleFunction(mu0=0.0284, a=1.22522, d0=7.10, d7=0)#14200)
dipole_function2 = SimpleGriegorievDipoleFunction(mu0=0.0284, a=1.22522, d0=7.10)

r_xe = np.array([0,0,0])
r_ar = np.array([2,1,3])

print(dipole_function1([r_xe,r_ar]))
print(dipole_function1.gradient([r_xe,r_ar],["+","-"]))
# Out:
# [-0.9295645005540366, -0.4647822502770183, -1.3943467508310547]
# [array([[-0.27679157, -0.37078691, -1.11236073],
#        [-0.37078691,  0.2793888 , -0.55618036],
#        [-1.11236073, -0.55618036, -1.20375884]]), array([[ 0.27679157,  0.37078691,  1.11236073],
#        [ 0.37078691, -0.2793888 ,  0.55618036],
#        [ 1.11236073,  0.55618036,  1.20375884]])]

# %% [markdown]
# \begin{align*}
# \dot{\textbf{C}}_k + i\omega \textbf{C}_k &= \frac{ie^{-i\textbf{k}\cdot \textbf{r}_\mu} }{\omega} \left(I - \frac{\textbf{k} \textbf{k}^T}{|\textbf{k}|} \right) \left( \frac{\partial \mu}{\partial \textbf{r}_{Ar} } \dot{\textbf{r}}_{Ar} + \frac{\partial \mu}{\partial \textbf{r}_{Xe} } \dot{\textbf{r}}_{Xe} \right)
# \\
# \omega &= ck
# \end{align*}

# %% [markdown]
# \begin{align*}
#     m_{Ar} \ddot{\textbf{r}}_{Ar}^{[\textbf{k}]} &= \sum_{i\neq \textbf{k}} \sum_{j \neq \textbf{k}} \dot{\textbf{r}}_{Ar}^{[i]} \frac{\partial \textbf{A}^{[j]} (\textbf{r}_\mu) }{\partial \textbf{r}^{[\textbf{k}]}_{Ar}}  \frac{\partial \mu^{[j]}}{\partial \textbf{r}_{Ar}^{[i]}}
#     - \sum_{j\neq\textbf{k}} \frac{\partial \textbf{A}^{[j]} (\textbf{r}_\mu) }{\partial t}  \frac{\partial \mu^{[j]}}{\partial \textbf{r}_{Ar}^{[\textbf{k}]}}
#     \\
#     m_{Ar} \ddot{\textbf{r}}_{Ar}^{[\textbf{k}1]}
#     &= - \sum_j \frac{\partial \textbf{A}^{[j]} (\textbf{r}_\mu) }{\partial t}  \frac{\partial \mu^{[j]}}{\partial \textbf{r}_{Ar}^{[\textbf{k}1]}}
#     - \sum_{j\neq \textbf{k}} \dot{\textbf{r}}_{Ar}^{[\textbf{k}]} \frac{\partial \textbf{A}^{[j]} (\textbf{r}_\mu) }{\partial \textbf{r}_{Ar}^{[\textbf{k}]}} \frac{\partial \mu^{[j]}}{\partial \textbf{r}_{Ar}^{[\textbf{k}1]}}
# \end{align*}
#
# Note that, for simplicity, we currently choose:
# \begin{align*}
#     \mathbf{x} &= \mathbf{k}
#     \\
#     \mathbf{y} &= \mathbf{k1}
#     \\
#     \mathbf{z} &= \mathbf{k2}
# \end{align*}

# %%
def gram_schmidt(vec1, vec2, vec3 ):
    orthonormal = [vec1 / np.sqrt(vec1 @ vec1)]

    for vec_i in [vec2,vec3]:
        
        for orthonormal_vec in orthonormal:
            vec_i -= orthonormal_vec.T @ vec_i * orthonormal_vec
            
        orthonormal.append(vec_i / np.sqrt(vec_i @ vec_i))

    return orthonormal

def epsilon_generator(k_vec):
    unit_vec_list = np.eye(3)
    foo = np.argsort(abs(k_vec))
    
    orthonormal = gram_schmidt(
        k_vec,
        unit_vec_list[foo[0]],
        unit_vec_list[foo[1]]
    )

    return np.array(orthonormal[1:])

k_vec = np.array([1e-2,1e-3,1e1],dtype=np.float64)
epsilon = np.array(epsilon_generator(k_vec))

print(epsilon)
print(k_vec @ epsilon.T)
print(epsilon @ epsilon.T)
# Out:
# [[-9.99998995e-08  9.99999995e-01 -9.99998995e-05]
#  [ 9.99999500e-01 -1.32348964e-23 -9.99999500e-04]]
# [-2.16840434e-19  0.00000000e+00]
# [[ 1.00000000e+00 -1.95178198e-23]
#  [-1.95178198e-23  1.00000000e+00]]

# %%
from simpleMD import compute_Hem
from utils import PBC_wrapping

"""
Note for implementing PBC for dipole.

The dipole function call and gradient should take vector connect
two point (which should be WRAPPED beforehand)
OR
WRAP the distance vector everytime it is computed in the dipole function
"""

class SimpleDynamicModel:
    def __init__(
            self, k_vec, epsilon, M, dipole_function, 
            potential=None, L=None):

        """
        Class of simple model for molecular dyanamic simulation
        for charged particle in EM field
        Args: 
        + q (list/ np.array of int): charge value of particles
        + k_vec (np.array): list of array of k vectors for the EM field
            have shape of n_mode x 3 with n_mode is int >= 1
        + epsilon (np.array): list or array of pairs of polarization vector modes
            for the EM field. Have the shape of n_mode x 2 x 3
        + k_const (float): constant for the Harmonic Oscillator
        + potential (None, MorsePotential, will add more class later):
            'engine' for potential or force computing
        """

        #assert len(q) == len(v) and len(v) == len(r)
        #assert C.shape[0] == k_vec.shape[0]

        if len(k_vec.shape) < 2:
            k_vec = k_vec.reshape(1,3)
        else: 
            assert k_vec.shape[1] == 3
        self.k_vec = k_vec

        if len(epsilon.shape) < 3:
            epsilon = epsilon.reshape(1,2,3)
        else:
            assert epsilon.shape[1] == 2 and epsilon.shape[2] == 3
        self.epsilon = epsilon

        self.potential = potential
      
        self.k = []; self.omega = []
        for vec in k_vec:
            k = np.sqrt(vec @ vec.T)
            self.k.append(k)
            self.omega.append( constants.c * k)
            
        self.M = np.tile(M[:,np.newaxis], (1,3) )
        self.dipole_func = dipole_function

        # list of unit vector along the wavevector k, hence epsilon_k
        self.epsilon_k = [self.k_vec[i] / self.k[i] for i in range(len(self.k))]

        self.change_of_basis_mat = [
            np.vstack([self.epsilon_k[i], self.epsilon[i]]) for i in range(len(self.k_vec))
        ]

        self.L = L
        self.potential.L = L
        self.dipole_func.L = L

    def dot_C(self, r, v, C):
        """
        Computing partial derivative of C w.r.t. time, a.k.a. C_dot
        Args:
        + r (np.array): list/array of postition of charged particles. Shape: n_particles x 3
        + v (np.array): list/array of velocities of charged particles. Shape: n_particles x 3
        + C (np.array): list/array of pair of modes
        """

        C_dot = []

        for j, k_vec in enumerate(self.k_vec):

            rk = r #np.einsum("ji,ki->kj",md.change_of_basis_mat[0], r)
            
            mu_grad = self.dipole_func.gradient(rk[0],rk[1])
            
            jk = 0
            
            for i, mu_grad_i in enumerate(mu_grad):
                jk += np.exp(-1j * k_vec @ r[i]) * mu_grad_i.T @ v[i] # * (2 * np.pi)**(-1.5)

            jk_transv = (np.eye(3) - np.outer(k_vec, k_vec) / (self.k[j]**2)) @ jk

            proj_jk_transv = np.array([
                jk_transv @ e for e in self.epsilon[j] 
                ])
            
            C_dot.append( -1j * self.omega[j] * C[j] + \
                (2 * np.pi * 1j / self.k[j]) * proj_jk_transv)

        C_dot = np.array(C_dot)
        return C_dot

    def compute_force(self, r, v, C):
        
        F = self.compute_transv_force(r=r, v=v, C=C)

        if self.potential is not None:
            F += self.potential.get_force(r)

        return F
    
    def compute_Hmat_transv(self,r,v):
        K = 0
        for i, vi in enumerate(v):
            K += 0.5 * (self.M[i] * vi) @ vi.T
        return K

    def compute_H(self, r, v, C):
        H_mat = self.compute_Hmat_transv(r=r, v=v)
        H_em = compute_Hem(self.k_vec, C)

        H_mat += self.potential.get_potential(r)

        return H_em, H_mat

    def pde_step(self, r, v, C):
        a = self.compute_force(r,v,C) / self.M
        C = self.dot_C(r,v,C)
        r = v
        return r, a, C

    def rk4_step(self, r, v, C, h):
        k1r, k1v, k1c = self.pde_step(
            r=r ,v=v, C=C)
        k2r, k2v, k2c = self.pde_step(
            r=r+k1r*h/2, v=v+k1v*h/2, C=C+k1c*h/2)
        k3r, k3v, k3c = self.pde_step(
            r=r+k2r*h/2, v=v+k2v*h/2, C=C+k2c*h/2)
        k4r, k4v, k4c = self.pde_step(
            r=r+k3r*h, v=v+k3v*h, C=C+k3c*h)

        r = r + (h/6) * (k1r + 2*k2r + 2*k3r + k4r)
        r = PBC_wrapping(r, self.L)
        v = v + (h/6) * (k1v + 2*k2v + 2*k3v + k4v)
        C = C + (h/6) * (k1c + 2*k2c + 2*k3c + k4c)

        return r, v, C

    def compute_transv_force(self, r, v, C):
        C_dot = self.dot_C(r,v,C)
        
        ma_list = []

        for j, rj in enumerate(r):
            _ma_ = np.array([0+0j,0+0j,0+0j])
            # sum over all wavevector k
            for l, k_vec in enumerate(self.k_vec):

                rk = np.einsum("ji,ki->kj",md.change_of_basis_mat[l], r)
            
                mu_grad = self.dipole_func.gradient(rk[0],rk[1])
                
                # k part
                vk  =  self.epsilon_k[l] @ v[j].T # projection of v on k_vec
                vk1 = self.epsilon[l][0] @ v[j].T # projection of v on epsilon_k1
                vk2 = self.epsilon[l][1] @ v[j].T # projection of v on epsilon_k2
                vkj = [vk1, vk2]

                # C[0] = 0;  C[1] = C_{k1}; C[2] = C_{k2}
                k = self.k[l]
                
                _ma_k = 0
                for m in [1,2]:
                    for n in [1,2]:
                    
                        _ma_k +=   vkj[n-1] * (1j * k * C[l][m-1] * np.exp(1j * k_vec @ rj) \
                                + np.conjugate(1j * k * C[l][m-1] * np.exp(1j * k_vec @ rj)) ) \
                                * mu_grad[j][n][m]
                        
                    foo =           (-C_dot[l][m-1] * np.exp(1j * k_vec @ rj) +  \
                        np.conjugate(-C_dot[l][m-1] * np.exp(1j * k_vec @ rj)) ) \
                        * mu_grad[j][0][m]
                    
                    _ma_k += foo
                    
                _ma_ += _ma_k * self.epsilon_k[l]

                # epsilon part
                for i in [1,2]:
                    _ma_ki = 0
                    for m in [1,2]:
                        _ma_ki +=       (-C_dot[l][m-1] * np.exp(1j * k_vec @ rj) + \
                            np.conjugate(-C_dot[l][m-1] * np.exp(1j * k_vec @ rj)) )\
                            * mu_grad[j][i][m]

                        _ma_ki +=   -vk * (1j * k * C[l][m-1] * np.exp(1j * k_vec @ rj) \
                            + np.conjugate(1j * k * C[l][m-1] * np.exp(1j * k_vec @ rj)) )\
                            * mu_grad[j][i][m]
                       
                    _ma_ += _ma_ki * self.epsilon[l][i-1]

            _ma_ /= constants.c

            ma_list.append(np.real(_ma_))

        return np.array(ma_list)


r_ar = np.array([ 4, 0, 0]) # Argon should be negative
r_xe = np.array([-4, 0, 0]) # Xenon should be positive

v_ar = np.array([-1, 0, 0]) * 1e1
v_xe = np.array([ 1, 0, 0]) * 1e1

Z_Ar = 18
m_Ar = Z_Ar * (m_p / m_e) + Z_Ar + (40 - Z_Ar) * (m_n / m_e) 
Z_Xe = 54
m_Xe = Z_Xe * (m_p / m_e) + Z_Xe + (131 - Z_Xe) * (m_n / m_e)

L = 16

"""
k_vec = np.array([
    np.array([1e0, 0  , 0  ],dtype = np.float64)/constants.c,
    np.array([  0, 1e0, 0  ],dtype = np.float64)/constants.c,
    np.array([  0, 0  , 1e0],dtype = np.float64)/constants.c,
    np.array([1e0, 1e0, 0  ],dtype = np.float64)/constants.c,
    np.array([  0, 1e0, 1e0],dtype = np.float64)/constants.c,
    np.array([1e0, 0  , 1e0],dtype = np.float64)/constants.c,
    np.array([1e0, 1e0, 1e0],dtype = np.float64)/constants.c,
])
"""
k_vec = np.array([
    np.array([  0, 1e0, 0  ],dtype = np.float64)/constants.c,
    np.array([  0, 1e1, 0  ],dtype = np.float64)/constants.c,
    np.array([  0, 1e2, 0  ],dtype = np.float64)/constants.c,
    #np.array([  0, 1e3, 0  ],dtype = np.float64)/constants.c,
])

epsilon_vec = np.stack([
    epsilon_generator(k) for k in k_vec
])

n_modes = len(k_vec)
#C = (np.random.rand(n_modes,2) + 1j * np.random.rand(n_modes,2)) * 1e3
C = (np.ones((n_modes,2)) + 1j * np.ones((n_modes,2))) * 1e3

assert n_modes == C.shape[0] and n_modes == len(k_vec) and n_modes == len(epsilon_vec)


dipole_func = SimpleGriegorievDipoleFunction(
    mu0=0.0124 , a=1.5121, d0=7.10, L = L
)

pure_epsilon = np.array([0.996, 1.904]) * 1.59360e-3
mixed_epsilon = 1.377 * 1.59360e-3

pure_sigma = np.array([3.41, 4.06]) * (1e-10 / 5.29177e-11)
mixed_sigma = 3.735 * (1e-10 / 5.29177e-11)

epsilon = construct_param_matrix(2,1,pure_epsilon,mixed_epsilon)
sigma = construct_param_matrix(2,1,pure_sigma,mixed_sigma)

lennardj = LennardJonesPotential(
    n_points = 2,
    epsilon = epsilon,
    sigma = sigma,
    L = L)

trajectory = {
    "initial r_Ar": r_ar, "initial r_Xe": r_xe,
    "initial v_Ar": v_ar, "initial v_Xe": v_xe,
    "k vector":k_vec,
    "H_rad" : [], "H_mat" : [], "total_H" : [],
    "dipole" : [],
    "steps" : [],
    "r" : []
}

# %%
r = np.vstack([r_xe,r_ar])
#r = np.array([r_ar])
v = np.vstack([v_xe,v_ar])
#v = np.array([v_ar])

M = np.array([m_Xe, m_Ar])
#M = np.array([1])

mu_grad = dipole_func.gradient(r[0],r[1])

h = 1e-4

md = SimpleDynamicModel(
    k_vec = k_vec, epsilon = epsilon_vec,potential=lennardj, M = M, 
    dipole_function = dipole_func, L = L,
)

n_steps = 25000

r_list = []

for i in range(n_steps):
    mu_grad = dipole_func.gradient(r[0], r[1])
    
    r, v, C = md.rk4_step(r,v,C,h)
    
    H_rad, H_mat = md.compute_H(r,v,C)
    total_H = np.sum(H_rad) + H_mat
    dipole = np.array(dipole_func(r[0],r[1]))
    dipole = dipole @ dipole.T
    
    trajectory["steps"].append(i)
    trajectory["H_rad"].append(H_rad)
    trajectory["H_mat"].append(H_mat)
    trajectory["total_H"].append(total_H)
    trajectory["dipole"].append(dipole)
    trajectory["r"].append(r)
    
    
    if i % 100 == 0:
        print("Iteration: ", i," Hamiltonian Sum: ",total_H)
# Out:
# Iteration:  0  Hamiltonian Sum:  (16057846.37075087+0j)
# Iteration:  100  Hamiltonian Sum:  (16057846.370750403+0j)
# Iteration:  200  Hamiltonian Sum:  (16057846.370749926+0j)
# Iteration:  300  Hamiltonian Sum:  (16057846.370749459+0j)
# Iteration:  400  Hamiltonian Sum:  (16057846.37074899+0j)
# Iteration:  500  Hamiltonian Sum:  (16057846.370748509+0j)
# Iteration:  600  Hamiltonian Sum:  (16057846.370748036+0j)
# Iteration:  700  Hamiltonian Sum:  (16057846.370747555+0j)
# Iteration:  800  Hamiltonian Sum:  (16057846.370747082+0j)
# Iteration:  900  Hamiltonian Sum:  (16057846.370746609+0j)
# Iteration:  1000  Hamiltonian Sum:  (16057846.370746149+0j)
# Iteration:  1100  Hamiltonian Sum:  (16057846.370745657+0j)
# Iteration:  1200  Hamiltonian Sum:  (16057846.370745167+0j)
# Iteration:  1300  Hamiltonian Sum:  (16057846.370744703+0j)
# Iteration:  1400  Hamiltonian Sum:  (16057846.370744266+0j)
# Iteration:  1500  Hamiltonian Sum:  (16057846.370743798+0j)
# Iteration:  1600  Hamiltonian Sum:  (16057846.370743329+0j)
# Iteration:  1700  Hamiltonian Sum:  (16057846.370742856+0j)
# Iteration:  1800  Hamiltonian Sum:  (16057846.370742388+0j)
# Iteration:  1900  Hamiltonian Sum:  (16057846.370741922+0j)
# Iteration:  2000  Hamiltonian Sum:  (16057846.370741427+0j)
# Iteration:  2100  Hamiltonian Sum:  (16057846.370740946+0j)
# Iteration:  2200  Hamiltonian Sum:  (16057846.370740484+0j)
# Iteration:  2300  Hamiltonian Sum:  (16057846.370740019+0j)
# Iteration:  2400  Hamiltonian Sum:  (16057846.37073956+0j)
# Iteration:  2500  Hamiltonian Sum:  (16057846.370739076+0j)
# Iteration:  2600  Hamiltonian Sum:  (16057846.370738607+0j)
# Iteration:  2700  Hamiltonian Sum:  (16057846.370738126+0j)
# Iteration:  2800  Hamiltonian Sum:  (16057846.370737657+0j)
# Iteration:  2900  Hamiltonian Sum:  (16057846.37073713+0j)
# Iteration:  3000  Hamiltonian Sum:  (16057846.370736362+0j)
# Iteration:  3100  Hamiltonian Sum:  (16057846.370734425+0j)
# Iteration:  3200  Hamiltonian Sum:  (16057846.370727574+0j)
# Iteration:  3300  Hamiltonian Sum:  (16057846.370776935+0j)
# Iteration:  3400  Hamiltonian Sum:  (16057846.371545758+0j)
# Iteration:  3500  Hamiltonian Sum:  (16057846.371404404+0j)
# Iteration:  3600  Hamiltonian Sum:  (16057846.370782882+0j)
# Iteration:  3700  Hamiltonian Sum:  (16057846.370670158+0j)
# Iteration:  3800  Hamiltonian Sum:  (16057846.370676976+0j)
# Iteration:  3900  Hamiltonian Sum:  (16057846.370678362+0j)
# Iteration:  4000  Hamiltonian Sum:  (16057846.37067818+0j)
# Iteration:  4100  Hamiltonian Sum:  (16057846.370677682+0j)
# Iteration:  4200  Hamiltonian Sum:  (16057846.370677127+0j)
# Iteration:  4300  Hamiltonian Sum:  (16057846.370676568+0j)
# Iteration:  4400  Hamiltonian Sum:  (16057846.370675994+0j)
# Iteration:  4500  Hamiltonian Sum:  (16057846.370675417+0j)
# Iteration:  4600  Hamiltonian Sum:  (16057846.370674841+0j)
# Iteration:  4700  Hamiltonian Sum:  (16057846.37067428+0j)
# Iteration:  4800  Hamiltonian Sum:  (16057846.370673724+0j)
# Iteration:  4900  Hamiltonian Sum:  (16057846.370673148+0j)
# Iteration:  5000  Hamiltonian Sum:  (16057846.370672572+0j)
# Iteration:  5100  Hamiltonian Sum:  (16057846.370671993+0j)
# Iteration:  5200  Hamiltonian Sum:  (16057846.370671397+0j)
# Iteration:  5300  Hamiltonian Sum:  (16057846.370670853+0j)
# Iteration:  5400  Hamiltonian Sum:  (16057846.370670294+0j)
# Iteration:  5500  Hamiltonian Sum:  (16057846.370669704+0j)
# Iteration:  5600  Hamiltonian Sum:  (16057846.370669117+0j)
# Iteration:  5700  Hamiltonian Sum:  (16057846.370668514+0j)
# Iteration:  5800  Hamiltonian Sum:  (16057846.370667947+0j)
# Iteration:  5900  Hamiltonian Sum:  (16057846.370667433+0j)
# Iteration:  6000  Hamiltonian Sum:  (16057846.370666862+0j)
# Iteration:  6100  Hamiltonian Sum:  (16057846.370666284+0j)
# Iteration:  6200  Hamiltonian Sum:  (16057846.370665705+0j)
# Iteration:  6300  Hamiltonian Sum:  (16057846.370665135+0j)
# Iteration:  6400  Hamiltonian Sum:  (16057846.370664597+0j)
# Iteration:  6500  Hamiltonian Sum:  (16057846.370664025+0j)
# Iteration:  6600  Hamiltonian Sum:  (16057846.370663453+0j)
# Iteration:  6700  Hamiltonian Sum:  (16057846.370662903+0j)
# Iteration:  6800  Hamiltonian Sum:  (16057846.370662332+0j)
# Iteration:  6900  Hamiltonian Sum:  (16057846.370661745+0j)
# Iteration:  7000  Hamiltonian Sum:  (16057846.37066102+0j)
# Iteration:  7100  Hamiltonian Sum:  (16057846.370660447+0j)
# Iteration:  7200  Hamiltonian Sum:  (16057846.370659858+0j)
# Iteration:  7300  Hamiltonian Sum:  (16057846.370659277+0j)
# Iteration:  7400  Hamiltonian Sum:  (16057846.370658701+0j)
# Iteration:  7500  Hamiltonian Sum:  (16057846.370658152+0j)
# Iteration:  7600  Hamiltonian Sum:  (16057846.37065755+0j)
# Iteration:  7700  Hamiltonian Sum:  (16057846.370656947+0j)
# Iteration:  7800  Hamiltonian Sum:  (16057846.370656384+0j)
# Iteration:  7900  Hamiltonian Sum:  (16057846.370655779+0j)
# Iteration:  8000  Hamiltonian Sum:  (16057846.370655201+0j)
# Iteration:  8100  Hamiltonian Sum:  (16057846.370654618+0j)
# Iteration:  8200  Hamiltonian Sum:  (16057846.37065403+0j)
# Iteration:  8300  Hamiltonian Sum:  (16057846.370653484+0j)
# Iteration:  8400  Hamiltonian Sum:  (16057846.370652927+0j)
# Iteration:  8500  Hamiltonian Sum:  (16057846.37065234+0j)
# Iteration:  8600  Hamiltonian Sum:  (16057846.370651744+0j)
# Iteration:  8700  Hamiltonian Sum:  (16057846.370651152+0j)
# Iteration:  8800  Hamiltonian Sum:  (16057846.370650586+0j)
# Iteration:  8900  Hamiltonian Sum:  (16057846.37065002+0j)
# Iteration:  9000  Hamiltonian Sum:  (16057846.370649433+0j)
# Iteration:  9100  Hamiltonian Sum:  (16057846.370648857+0j)
# Iteration:  9200  Hamiltonian Sum:  (16057846.37064831+0j)
# Iteration:  9300  Hamiltonian Sum:  (16057846.370647747+0j)
# Iteration:  9400  Hamiltonian Sum:  (16057846.37064716+0j)
# Iteration:  9500  Hamiltonian Sum:  (16057846.370646596+0j)
# Iteration:  9600  Hamiltonian Sum:  (16057846.37064602+0j)
# Iteration:  9700  Hamiltonian Sum:  (16057846.370645437+0j)
# Iteration:  9800  Hamiltonian Sum:  (16057846.370644828+0j)
# Iteration:  9900  Hamiltonian Sum:  (16057846.370644096+0j)
# Iteration:  10000  Hamiltonian Sum:  (16057846.370642902+0j)
# Iteration:  10100  Hamiltonian Sum:  (16057846.370639194+0j)
# Iteration:  10200  Hamiltonian Sum:  (16057846.370632973+0j)
# Iteration:  10300  Hamiltonian Sum:  (16057846.370956598+0j)
# Iteration:  10400  Hamiltonian Sum:  (16057846.370906563+0j)
# Iteration:  10500  Hamiltonian Sum:  (16057846.371169612+0j)
# Iteration:  10600  Hamiltonian Sum:  (16057846.370598745+0j)
# Iteration:  10700  Hamiltonian Sum:  (16057846.370593814+0j)
# Iteration:  10800  Hamiltonian Sum:  (16057846.370597746+0j)
# Iteration:  10900  Hamiltonian Sum:  (16057846.3705982+0j)
# Iteration:  11000  Hamiltonian Sum:  (16057846.37059795+0j)
# Iteration:  11100  Hamiltonian Sum:  (16057846.37059755+0j)
# Iteration:  11200  Hamiltonian Sum:  (16057846.370597117+0j)
# Iteration:  11300  Hamiltonian Sum:  (16057846.370596703+0j)
# Iteration:  11400  Hamiltonian Sum:  (16057846.370596256+0j)
# Iteration:  11500  Hamiltonian Sum:  (16057846.370595813+0j)
# Iteration:  11600  Hamiltonian Sum:  (16057846.370595358+0j)
# Iteration:  11700  Hamiltonian Sum:  (16057846.370594922+0j)
# Iteration:  11800  Hamiltonian Sum:  (16057846.370594481+0j)
# Iteration:  11900  Hamiltonian Sum:  (16057846.370594053+0j)
# Iteration:  12000  Hamiltonian Sum:  (16057846.370593598+0j)
# Iteration:  12100  Hamiltonian Sum:  (16057846.370593162+0j)
# Iteration:  12200  Hamiltonian Sum:  (16057846.370592695+0j)
# Iteration:  12300  Hamiltonian Sum:  (16057846.370592229+0j)
# Iteration:  12400  Hamiltonian Sum:  (16057846.370591773+0j)
# Iteration:  12500  Hamiltonian Sum:  (16057846.370591328+0j)
# Iteration:  12600  Hamiltonian Sum:  (16057846.370590895+0j)
# Iteration:  12700  Hamiltonian Sum:  (16057846.37059043+0j)
# Iteration:  12800  Hamiltonian Sum:  (16057846.370589977+0j)
# Iteration:  12900  Hamiltonian Sum:  (16057846.370589536+0j)
# Iteration:  13000  Hamiltonian Sum:  (16057846.370589102+0j)
# Iteration:  13100  Hamiltonian Sum:  (16057846.37058868+0j)
# Iteration:  13200  Hamiltonian Sum:  (16057846.370588258+0j)
# Iteration:  13300  Hamiltonian Sum:  (16057846.370587828+0j)
# Iteration:  13400  Hamiltonian Sum:  (16057846.370587384+0j)
# Iteration:  13500  Hamiltonian Sum:  (16057846.370586935+0j)
# Iteration:  13600  Hamiltonian Sum:  (16057846.370586496+0j)
# Iteration:  13700  Hamiltonian Sum:  (16057846.370586064+0j)
# Iteration:  13800  Hamiltonian Sum:  (16057846.37058563+0j)
# Iteration:  13900  Hamiltonian Sum:  (16057846.37058507+0j)
# Iteration:  14000  Hamiltonian Sum:  (16057846.370584624+0j)
# Iteration:  14100  Hamiltonian Sum:  (16057846.370584168+0j)
# Iteration:  14200  Hamiltonian Sum:  (16057846.370583726+0j)
# Iteration:  14300  Hamiltonian Sum:  (16057846.37058328+0j)
# Iteration:  14400  Hamiltonian Sum:  (16057846.370582832+0j)
# Iteration:  14500  Hamiltonian Sum:  (16057846.370582383+0j)
# Iteration:  14600  Hamiltonian Sum:  (16057846.370581966+0j)
# Iteration:  14700  Hamiltonian Sum:  (16057846.370581515+0j)
# Iteration:  14800  Hamiltonian Sum:  (16057846.370581072+0j)
# Iteration:  14900  Hamiltonian Sum:  (16057846.370580612+0j)
# Iteration:  15000  Hamiltonian Sum:  (16057846.37058017+0j)
# Iteration:  15100  Hamiltonian Sum:  (16057846.37057971+0j)
# Iteration:  15200  Hamiltonian Sum:  (16057846.370579276+0j)
# Iteration:  15300  Hamiltonian Sum:  (16057846.370578831+0j)
# Iteration:  15400  Hamiltonian Sum:  (16057846.370578386+0j)
# Iteration:  15500  Hamiltonian Sum:  (16057846.370577926+0j)
# Iteration:  15600  Hamiltonian Sum:  (16057846.370577486+0j)
# Iteration:  15700  Hamiltonian Sum:  (16057846.370577043+0j)
# Iteration:  15800  Hamiltonian Sum:  (16057846.370576603+0j)
# Iteration:  15900  Hamiltonian Sum:  (16057846.370576167+0j)
# Iteration:  16000  Hamiltonian Sum:  (16057846.370575726+0j)
# Iteration:  16100  Hamiltonian Sum:  (16057846.370575262+0j)
# Iteration:  16200  Hamiltonian Sum:  (16057846.3705748+0j)
# Iteration:  16300  Hamiltonian Sum:  (16057846.370574363+0j)
# Iteration:  16400  Hamiltonian Sum:  (16057846.370573914+0j)
# Iteration:  16500  Hamiltonian Sum:  (16057846.370573469+0j)
# Iteration:  16600  Hamiltonian Sum:  (16057846.370573021+0j)
# Iteration:  16700  Hamiltonian Sum:  (16057846.370572567+0j)
# Iteration:  16800  Hamiltonian Sum:  (16057846.370572079+0j)
# Iteration:  16900  Hamiltonian Sum:  (16057846.370571394+0j)
# Iteration:  17000  Hamiltonian Sum:  (16057846.370569916+0j)
# Iteration:  17100  Hamiltonian Sum:  (16057846.370565755+0j)
# Iteration:  17200  Hamiltonian Sum:  (16057846.370588537+0j)
# Iteration:  17300  Hamiltonian Sum:  (16057846.370981446+0j)
# Iteration:  17400  Hamiltonian Sum:  (16057846.370745426+0j)
# Iteration:  17500  Hamiltonian Sum:  (16057846.37072452+0j)
# Iteration:  17600  Hamiltonian Sum:  (16057846.370538358+0j)
# Iteration:  17700  Hamiltonian Sum:  (16057846.370539432+0j)
# Iteration:  17800  Hamiltonian Sum:  (16057846.370541273+0j)
# Iteration:  17900  Hamiltonian Sum:  (16057846.370541304+0j)
# Iteration:  18000  Hamiltonian Sum:  (16057846.370540911+0j)
# Iteration:  18100  Hamiltonian Sum:  (16057846.370540434+0j)
# Iteration:  18200  Hamiltonian Sum:  (16057846.370539932+0j)
# Iteration:  18300  Hamiltonian Sum:  (16057846.370539417+0j)
# Iteration:  18400  Hamiltonian Sum:  (16057846.370538913+0j)
# Iteration:  18500  Hamiltonian Sum:  (16057846.370538404+0j)
# Iteration:  18600  Hamiltonian Sum:  (16057846.3705379+0j)
# Iteration:  18700  Hamiltonian Sum:  (16057846.370537387+0j)
# Iteration:  18800  Hamiltonian Sum:  (16057846.370536862+0j)
# Iteration:  18900  Hamiltonian Sum:  (16057846.370536348+0j)
# Iteration:  19000  Hamiltonian Sum:  (16057846.370535832+0j)
# Iteration:  19100  Hamiltonian Sum:  (16057846.370535323+0j)
# Iteration:  19200  Hamiltonian Sum:  (16057846.370534802+0j)
# Iteration:  19300  Hamiltonian Sum:  (16057846.370534293+0j)
# Iteration:  19400  Hamiltonian Sum:  (16057846.37053379+0j)
# Iteration:  19500  Hamiltonian Sum:  (16057846.370533276+0j)
# Iteration:  19600  Hamiltonian Sum:  (16057846.370532773+0j)
# Iteration:  19700  Hamiltonian Sum:  (16057846.370532263+0j)
# Iteration:  19800  Hamiltonian Sum:  (16057846.37053176+0j)
# Iteration:  19900  Hamiltonian Sum:  (16057846.370531252+0j)
# Iteration:  20000  Hamiltonian Sum:  (16057846.37053074+0j)
# Iteration:  20100  Hamiltonian Sum:  (16057846.370530233+0j)
# Iteration:  20200  Hamiltonian Sum:  (16057846.370529724+0j)
# Iteration:  20300  Hamiltonian Sum:  (16057846.370529225+0j)
# Iteration:  20400  Hamiltonian Sum:  (16057846.370528713+0j)
# Iteration:  20500  Hamiltonian Sum:  (16057846.370528195+0j)
# Iteration:  20600  Hamiltonian Sum:  (16057846.370527687+0j)
# Iteration:  20700  Hamiltonian Sum:  (16057846.37052718+0j)
# Iteration:  20800  Hamiltonian Sum:  (16057846.370526666+0j)
# Iteration:  20900  Hamiltonian Sum:  (16057846.37052615+0j)
# Iteration:  21000  Hamiltonian Sum:  (16057846.370525638+0j)
# Iteration:  21100  Hamiltonian Sum:  (16057846.370525131+0j)
# Iteration:  21200  Hamiltonian Sum:  (16057846.370524619+0j)
# Iteration:  21300  Hamiltonian Sum:  (16057846.370524123+0j)
# Iteration:  21400  Hamiltonian Sum:  (16057846.370523602+0j)
# Iteration:  21500  Hamiltonian Sum:  (16057846.3705231+0j)
# Iteration:  21600  Hamiltonian Sum:  (16057846.370522588+0j)
# Iteration:  21700  Hamiltonian Sum:  (16057846.370522073+0j)
# Iteration:  21800  Hamiltonian Sum:  (16057846.37052157+0j)
# Iteration:  21900  Hamiltonian Sum:  (16057846.370521063+0j)
# Iteration:  22000  Hamiltonian Sum:  (16057846.370520543+0j)
# Iteration:  22100  Hamiltonian Sum:  (16057846.370519906+0j)
# Iteration:  22200  Hamiltonian Sum:  (16057846.37051939+0j)
# Iteration:  22300  Hamiltonian Sum:  (16057846.370518878+0j)
# Iteration:  22400  Hamiltonian Sum:  (16057846.370518373+0j)
# Iteration:  22500  Hamiltonian Sum:  (16057846.370517857+0j)
# Iteration:  22600  Hamiltonian Sum:  (16057846.370517341+0j)
# Iteration:  22700  Hamiltonian Sum:  (16057846.37051684+0j)
# Iteration:  22800  Hamiltonian Sum:  (16057846.37051633+0j)
# Iteration:  22900  Hamiltonian Sum:  (16057846.370515835+0j)
# Iteration:  23000  Hamiltonian Sum:  (16057846.370515328+0j)
# Iteration:  23100  Hamiltonian Sum:  (16057846.370514812+0j)
# Iteration:  23200  Hamiltonian Sum:  (16057846.370514316+0j)
# Iteration:  23300  Hamiltonian Sum:  (16057846.370513806+0j)
# Iteration:  23400  Hamiltonian Sum:  (16057846.370513417+0j)
# Iteration:  23500  Hamiltonian Sum:  (16057846.370512897+0j)
# Iteration:  23600  Hamiltonian Sum:  (16057846.370512387+0j)
# Iteration:  23700  Hamiltonian Sum:  (16057846.37051188+0j)
# Iteration:  23800  Hamiltonian Sum:  (16057846.370511364+0j)
# Iteration:  23900  Hamiltonian Sum:  (16057846.37051085+0j)
# Iteration:  24000  Hamiltonian Sum:  (16057846.370510362+0j)
# Iteration:  24100  Hamiltonian Sum:  (16057846.37050985+0j)
# Iteration:  24200  Hamiltonian Sum:  (16057846.370509332+0j)
# Iteration:  24300  Hamiltonian Sum:  (16057846.37050883+0j)
# Iteration:  24400  Hamiltonian Sum:  (16057846.37050832+0j)
# Iteration:  24500  Hamiltonian Sum:  (16057846.370507823+0j)
# Iteration:  24600  Hamiltonian Sum:  (16057846.370507317+0j)
# Iteration:  24700  Hamiltonian Sum:  (16057846.37050682+0j)
# Iteration:  24800  Hamiltonian Sum:  (16057846.37050631+0j)
# Iteration:  24900  Hamiltonian Sum:  (16057846.370505817+0j)

# %%
import pickle

with open("result_plot//trajectory_1.pkl","wb") as handle:
    pickle.dump(trajectory,handle)

# %%
with open("result_plot//trajectory_1.pkl","rb") as handle:
    trajectory_ = pickle.load(handle)
    
print("initial r_Ar: ", trajectory_["initial r_Ar"])
print("initial r_Xe: ", trajectory_["initial r_Xe"])
print("initial v_Ar: ", trajectory_["initial v_Ar"])
print("initial v_Xe: ", trajectory_["initial v_Xe"])
print("Cavity mode: ", trajectory_["k vector"])

fig,ax = plt.subplots(2,2,figsize = (12,6))
steps_ = np.array(steps)*h

ax[0][0].plot(steps_,trajectory_["total_H"])
ax[0][0].set_ylabel("Total Hamiltonian")

ax[0][1].plot(steps_,trajectory_["H_mat"])
ax[0][1].set_ylabel("Total atomic kinetic and potential")

linestyle = [
    "solid","dashed",(0, (1, 1)), 
    "dashdot", (5, (10, 3)), "solid", 
    (0, (5, 1)), (0, (3, 10, 1, 10))
   
]

H_rad_list_ = np.array(trajectory_["H_rad"])
for i in range(H_rad_list_.shape[1]):
    ax[1][0].plot(steps_,H_rad_list_[:,i], label = str(i), linestyle = linestyle[i])
    ax[1][0].set_ylabel("Radiation Hamiltonian")
    ax[1][0].set_xlabel("Time")

ax[1,0].legend()

ax[1][1].plot(steps_,dipole_list)
ax[1][1].set_ylabel("Dipole")
ax[1][1].set_xlabel("Time")

fig.savefig("foo.jpeg",dpi=300)
# Out:
# initial r_Ar:  [4 0 0]
# initial r_Xe:  [-4  0  0]
# initial v_Ar:  [-10.   0.   0.]
# initial v_Xe:  [10.  0.  0.]
# Cavity mode:  [[0.         0.00729927 0.        ]
#  [0.         0.0729927  0.        ]
#  [0.         0.72992701 0.        ]]
# C:\Users\hoang\miniconda3\lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# C:\Users\hoang\miniconda3\lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
np.array(trajectory_["r"]).shape

r_list = []
for i, r in enumerate(trajectory_["r"]):
    if i % 25 == 0:
        r_list.append(r)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation

# %matplotlib inline

assert len(r_list) <= 3000

fig, ax = plt.subplots(1,2,figsize = (12,6))

scats = []

R = r_list[0]

scats.append( ax[0].scatter(R[0, 0], R[0, 1], s = 40) )
scats.append( ax[1].scatter(R[0, 2], R[0, 1], s = 40) )

scats.append( ax[0].scatter(R[1, 0], R[1, 1], s = 20) )
scats.append( ax[1].scatter(R[1, 2], R[1, 1], s = 20) )

ax[0].set_xlim(-L/2,L/2)
ax[0].set_ylim(-L/2,L/2)
ax[1].set_xlim(-L/2,L/2)
ax[1].set_ylim(-L/2,L/2)

def animate(i):
    R = r_list[i]

    scats[0].set_offsets(
        np.vstack([R[0, 0], R[0, 1]]).T
    )
    scats[1].set_offsets(
        np.vstack([R[0, 2], R[0, 1]]).T
    )

    scats[2].set_offsets(
        np.vstack([R[1, 0], R[1, 1]]).T
    )
    scats[3].set_offsets(
        np.vstack([R[1, 2], R[1, 1]]).T
    )
    
ani = animation.FuncAnimation(fig, func=animate, frames= len(r_list), interval = 0.1)

#ani.save('result_plot/colliding_in_EM.html', writer=animation.HTMLWriter(fps= 1))

ani.save(filename="result_plot/colliding_in_EM.gif", writer="pillow")

# %%
r_list
# Out:
# [array([[-3.99950000e+00, -2.91515615e-17, -9.49487377e-16],
#         [ 3.99900000e+00, -1.90948737e-16,  3.10966903e-15]]),
#  array([[-3.89950000e+00,  8.51592571e-14,  2.09184904e-13],
#         [ 3.79900000e+00,  5.57810690e-13, -6.85102124e-13]]),
#  array([[-3.79950000e+00,  1.69607680e-13,  4.17337674e-13],
#         [ 3.59900000e+00,  1.11096527e-12, -1.36682390e-12]]),
#  array([[-3.69950000e+00,  2.54391366e-13,  6.27732766e-13],
#         [ 3.39900000e+00,  1.66631589e-12, -2.05588952e-12]]),
#  array([[-3.59950000e+00,  3.39155528e-13,  8.37355534e-13],
#         [ 3.19900000e+00,  2.22153863e-12, -2.74242569e-12]]),
#  array([[-3.49950000e+00,  4.23854975e-13,  1.04688044e-12],
#         [ 2.99900000e+00,  2.77633747e-12, -3.42864134e-12]]),
#  array([[-3.39950000e+00,  5.08585316e-13,  1.25664026e-12],
#         [ 2.79900000e+00,  3.33133867e-12, -4.11562638e-12]]),
#  array([[-3.29950000e+00,  5.93294620e-13,  1.46629319e-12],
#         [ 2.59900000e+00,  3.88620208e-12, -4.80226136e-12]]),
#  array([[-3.19950000e+00,  6.77962318e-13,  1.67594988e-12],
#         [ 2.39900000e+00,  4.44079295e-12, -5.48890860e-12]]),
#  array([[-3.09950000e+00,  7.62542334e-13,  1.88562984e-12],
#         [ 2.19900001e+00,  4.99480950e-12, -6.17563210e-12]]),
#  array([[-2.99950000e+00,  8.46894717e-13,  2.09529595e-12],
#         [ 1.99900001e+00,  5.54733502e-12, -6.86231022e-12]]),
#  array([[-2.89950001e+00,  9.30685326e-13,  2.30496422e-12],
#         [ 1.79900002e+00,  6.09618081e-12, -7.54899540e-12]]),
#  array([[-2.79950002e+00,  1.01308520e-12,  2.51463463e-12],
#         [ 1.59900005e+00,  6.63591705e-12, -8.23568763e-12]]),
#  array([[-2.69950004e+00,  1.09203845e-12,  2.72430335e-12],
#         [ 1.39900012e+00,  7.15307737e-12, -8.92237430e-12]]),
#  array([[-2.59950009e+00,  1.16245294e-12,  2.93397261e-12],
#         [ 1.19900029e+00,  7.61430751e-12, -9.60906274e-12]]),
#  array([[-2.49950023e+00,  1.21171257e-12,  3.14364233e-12],
#         [ 9.99000743e-01,  7.93697046e-12, -1.02957527e-11]]),
#  array([[-2.39950062e+00,  1.20856109e-12,  3.35331284e-12],
#         [ 7.99002019e-01,  7.91633521e-12, -1.09824452e-11]]),
#  array([[-2.29950184e+00,  1.07556584e-12,  3.56298728e-12],
#         [ 5.99006015e-01,  7.04521804e-12, -1.16691506e-11]]),
#  array([[-2.19950614e+00,  6.20937825e-13,  3.77267857e-12],
#         [ 3.99020107e-01,  4.06743674e-12, -1.23559112e-11]]),
#  array([[-2.09952373e+00, -6.29896836e-13,  3.98245617e-12],
#         [ 1.99077729e-01, -4.12518983e-12, -1.30429545e-11]]),
#  array([[-1.99961063e+00, -3.84476795e-12,  4.19277613e-12],
#         [-6.37662371e-04, -2.51807900e-11, -1.37317740e-11]]),
#  array([[-1.90015962e+00, -1.17808478e-11,  4.40753344e-12],
#         [-1.98839666e-01, -7.71816514e-11, -1.44351263e-11]]),
#  array([[-1.80484511e+00, -2.83227231e-11,  4.67223197e-12],
#         [-3.83494202e-01, -1.87331524e-10, -1.53020413e-11]]),
#  array([[-1.74490689e+00, -2.86432175e-11,  5.47467690e-12],
#         [-4.52287740e-01, -2.77335797e-10, -1.79301312e-11]]),
#  array([[-1.75967240e+00,  5.87841903e-12,  7.61422485e-12],
#         [-2.76418880e-01, -5.26882767e-10, -2.49373713e-11]]),
#  array([[-1.79727591e+00,  4.81493575e-11,  1.02272486e-11],
#         [-2.57532028e-02, -8.08575679e-10, -3.34952933e-11]]),
#  array([[-1.83727806e+00,  9.47276371e-11,  1.28973164e-11],
#         [ 2.32768283e-01, -1.02436735e-09, -4.22400407e-11]]),
#  array([[-1.87756725e+00,  1.43010022e-10,  1.55748651e-11],
#         [ 4.92229828e-01, -1.20783058e-09, -5.10092886e-11]]),
#  array([[-1.91790234e+00,  1.91957949e-10,  1.82536860e-11],
#         [ 7.51841717e-01, -1.37788889e-09, -5.97827033e-11]]),
#  array([[-1.95824668e+00,  2.41170311e-10,  2.09327749e-11],
#         [ 1.01148390e+00, -1.54250450e-09, -6.85569955e-11]]),
#  array([[-1.99859325e+00,  2.90488628e-10,  2.36119305e-11],
#         [ 1.27113339e+00, -1.70491925e-09, -7.73315064e-11]]),
#  array([[-2.03894045e+00,  3.39849557e-10,  2.62911052e-11],
#         [ 1.53078491e+00, -1.86644502e-09, -8.61060797e-11]]),
#  array([[-2.07928783e+00,  3.89227652e-10,  2.89702860e-11],
#         [ 1.79043706e+00, -2.02761184e-09, -9.48806728e-11]]),
#  array([[-2.11963528e+00,  4.38612669e-10,  3.16494689e-11],
#         [ 2.05008943e+00, -2.18863376e-09, -1.03655273e-10]]),
#  array([[-2.15998276e+00,  4.88000480e-10,  3.43286525e-11],
#         [ 2.30974188e+00, -2.34959719e-09, -1.12429876e-10]]),
#  array([[-2.20033024e+00,  5.37389418e-10,  3.70078365e-11],
#         [ 2.56939437e+00, -2.51053700e-09, -1.21204479e-10]]),
#  array([[-2.24067773e+00,  5.86778810e-10,  3.96870206e-11],
#         [ 2.82904686e+00, -2.67146729e-09, -1.29979084e-10]]),
#  array([[-2.28102522e+00,  6.36168387e-10,  4.23662048e-11],
#         [ 3.08869936e+00, -2.83239374e-09, -1.38753688e-10]]),
#  array([[-2.32137272e+00,  6.85558038e-10,  4.50453890e-11],
#         [ 3.34835187e+00, -2.99331863e-09, -1.47528292e-10]]),
#  array([[-2.36172021e+00,  7.34947718e-10,  4.77245733e-11],
#         [ 3.60800437e+00, -3.15424289e-09, -1.56302897e-10]]),
#  array([[-2.40206770e+00,  7.84337411e-10,  5.04037575e-11],
#         [ 3.86765688e+00, -3.31516690e-09, -1.65077501e-10]]),
#  array([[-2.44241520e+00,  8.33727109e-10,  5.30829417e-11],
#         [ 4.12730939e+00, -3.47609082e-09, -1.73852106e-10]]),
#  array([[-2.48276269e+00,  8.83116809e-10,  5.57621260e-11],
#         [ 4.38696189e+00, -3.63701468e-09, -1.82626710e-10]]),
#  array([[-2.52311018e+00,  9.32506509e-10,  5.84413102e-11],
#         [ 4.64661440e+00, -3.79793854e-09, -1.91401315e-10]]),
#  array([[-2.56345767e+00,  9.81896210e-10,  6.11204944e-11],
#         [ 4.90626691e+00, -3.95886238e-09, -2.00175920e-10]]),
#  array([[-2.60380517e+00,  1.03128591e-09,  6.37996787e-11],
#         [ 5.16591941e+00, -4.11978622e-09, -2.08950524e-10]]),
#  array([[-2.64415266e+00,  1.08067561e-09,  6.64788629e-11],
#         [ 5.42557192e+00, -4.28071007e-09, -2.17725129e-10]]),
#  array([[-2.68450015e+00,  1.13006531e-09,  6.91580472e-11],
#         [ 5.68522443e+00, -4.44163391e-09, -2.26499733e-10]]),
#  array([[-2.72484765e+00,  1.17945501e-09,  7.18372314e-11],
#         [ 5.94487694e+00, -4.60255775e-09, -2.35274338e-10]]),
#  array([[-2.76519514e+00,  1.22884472e-09,  7.45164156e-11],
#         [ 6.20452944e+00, -4.76348159e-09, -2.44048942e-10]]),
#  array([[-2.80554263e+00,  1.27823442e-09,  7.71955999e-11],
#         [ 6.46418195e+00, -4.92440544e-09, -2.52823547e-10]]),
#  array([[-2.84589013e+00,  1.32762412e-09,  7.98747841e-11],
#         [ 6.72383446e+00, -5.08532928e-09, -2.61598151e-10]]),
#  array([[-2.88623762e+00,  1.37701382e-09,  8.25539684e-11],
#         [ 6.98348696e+00, -5.24625313e-09, -2.70372756e-10]]),
#  array([[-2.92658511e+00,  1.42640352e-09,  8.52331526e-11],
#         [ 7.24313947e+00, -5.40717697e-09, -2.79147361e-10]]),
#  array([[-2.96693260e+00,  1.47579322e-09,  8.79123368e-11],
#         [ 7.50279197e+00, -5.56810082e-09, -2.87921965e-10]]),
#  array([[-3.00728010e+00,  1.52518292e-09,  9.05915206e-11],
#         [ 7.76244448e+00, -5.72902467e-09, -2.96696568e-10]]),
#  array([[-3.04762759e+00,  1.57457263e-09,  9.32707038e-11],
#         [-7.97790302e+00, -5.88994854e-09, -3.05471169e-10]]),
#  array([[-3.08797508e+00,  1.62396213e-09,  9.59498869e-11],
#         [-7.71825053e+00, -6.05087666e-09, -3.14245770e-10]]),
#  array([[-3.12832256e+00,  1.67335096e-09,  9.86290705e-11],
#         [-7.45859806e+00, -6.21181935e-09, -3.23020372e-10]]),
#  array([[-3.16867003e+00,  1.72273810e-09,  1.01308256e-10],
#         [-7.19894564e+00, -6.37279815e-09, -3.31794980e-10]]),
#  array([[-3.20901745e+00,  1.77212109e-09,  1.03987445e-10],
#         [-6.93929334e+00, -6.53386646e-09, -3.40569601e-10]]),
#  array([[-3.24936477e+00,  1.82149383e-09,  1.06666647e-10],
#         [-6.67964140e+00, -6.69515668e-09, -3.49344265e-10]]),
#  array([[-3.28971177e+00,  1.87084141e-09,  1.09345894e-10],
#         [-6.41999053e+00, -6.85699744e-09, -3.58119075e-10]]),
#  array([[-3.33005765e+00,  1.92012774e-09,  1.12025311e-10],
#         [-6.16034329e+00, -7.02020566e-09, -3.66894441e-10]]),
#  array([[-3.37039930e+00,  1.96926838e-09,  1.14705468e-10],
#         [-5.90070992e+00, -7.18682049e-09, -3.75672231e-10]]),
#  array([[-3.41072196e+00,  2.01808580e-09,  1.17389453e-10],
#         [-5.64113876e+00, -7.36198742e-09, -3.84462558e-10]]),
#  array([[-3.45094044e+00,  2.06639284e-09,  1.20098049e-10],
#         [-5.38190879e+00, -7.55913627e-09, -3.93333492e-10]]),
#  array([[-3.49041780e+00,  2.11636071e-09,  1.23016526e-10],
#         [-5.12510606e+00, -7.81758698e-09, -4.02891805e-10]]),
#  array([[-3.52288266e+00,  2.20942567e-09,  1.28379270e-10],
#         [-4.89126997e+00, -8.29963212e-09, -4.20455342e-10]]),
#  array([[-3.50583032e+00,  2.70236447e-09,  1.54790150e-10],
#         [-4.81960783e+00, -9.97241030e-09, -5.06953696e-10]]),
#  array([[-3.42162361e+00,  3.79745451e-09,  2.14066069e-10],
#         [-4.96788319e+00, -1.37274742e-08, -7.01088443e-10]]),
#  array([[-3.32328980e+00,  5.04924116e-09,  2.81288892e-10],
#         [-5.16242624e+00, -1.79488109e-08, -9.21250117e-10]]),
#  array([[-3.22351485e+00,  6.32566302e-09,  3.49425330e-10],
#         [-5.36168920e+00, -2.21807696e-08, -1.14440397e-09]]),
#  array([[-3.12355512e+00,  7.60766806e-09,  4.17688499e-10],
#         [-5.56155730e+00, -2.63999328e-08, -1.36797289e-09]]),
#  array([[-3.02356407e+00,  8.89139615e-09,  4.85974335e-10],
#         [-5.76152797e+00, -3.06120455e-08, -1.59161604e-09]]),
#  array([[-2.92356643e+00,  1.01757408e-08,  5.54265138e-10],
#         [-5.96152026e+00, -3.48210439e-08, -1.81527546e-09]]),
#  array([[-2.82356714e+00,  1.14603205e-08,  6.22557219e-10],
#         [-6.16151794e+00, -3.90287391e-08, -2.03893907e-09]]),
#  array([[-2.72356737e+00,  1.27449924e-08,  6.90849675e-10],
#         [-6.36151716e+00, -4.32358993e-08, -2.26260390e-09]]),
#  array([[-2.62356746e+00,  1.40297010e-08,  7.59142252e-10],
#         [-6.56151688e+00, -4.74428419e-08, -2.48626913e-09]]),
#  array([[-2.52356749e+00,  1.53144242e-08,  8.27434873e-10],
#         [-6.76151677e+00, -5.16496961e-08, -2.70993450e-09]]),
#  array([[-2.42356751e+00,  1.65991533e-08,  8.95727510e-10],
#         [-6.96151672e+00, -5.58565147e-08, -2.93359993e-09]]),
#  array([[-2.32356751e+00,  1.78838848e-08,  9.64020153e-10],
#         [-7.16151670e+00, -6.00633189e-08, -3.15726537e-09]]),
#  array([[-2.22356752e+00,  1.91686173e-08,  1.03231280e-09],
#         [-7.36151669e+00, -6.42701173e-08, -3.38093083e-09]]),
#  array([[-2.12356752e+00,  2.04533502e-08,  1.10060545e-09],
#         [-7.56151669e+00, -6.84769133e-08, -3.60459629e-09]]),
#  array([[-2.02356752e+00,  2.17380832e-08,  1.16889810e-09],
#         [-7.76151669e+00, -7.26837084e-08, -3.82826175e-09]]),
#  array([[-1.92356752e+00,  2.30228163e-08,  1.23719075e-09],
#         [-7.96151668e+00, -7.68905031e-08, -4.05192722e-09]]),
#  array([[-1.82356752e+00,  2.43075494e-08,  1.30548339e-09],
#         [ 7.83848332e+00, -8.10972978e-08, -4.27559268e-09]]),
#  array([[-1.72356752e+00,  2.55922825e-08,  1.37377604e-09],
#         [ 7.63848332e+00, -8.53040924e-08, -4.49925815e-09]]),
#  array([[-1.62356752e+00,  2.68770156e-08,  1.44206869e-09],
#         [ 7.43848332e+00, -8.95108870e-08, -4.72292361e-09]]),
#  array([[-1.52356752e+00,  2.81617488e-08,  1.51036134e-09],
#         [ 7.23848332e+00, -9.37176816e-08, -4.94658908e-09]])]
